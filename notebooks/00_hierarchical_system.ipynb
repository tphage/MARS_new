# %% [markdown]
# # Hierarchical System Orchestration
#
# This notebook runs through the entire hierarchical system:
# 1. **System 1**: Property Extraction (runs once)
# 2. **System 2**: Material Discovery → **System 3**: Manufacturing Assessment
# 3. If System 3 rejects materials (status="blocked"), loops back to System 2 (up to 3 iterations)
# 4. Stops when System 3 returns manufacturable candidate or max iterations reached
#
# **Workflow**:
# ```
# System 1 → System 2 → System 3
#               ↓         ↓
#            (if blocked) ↓
#               ←─────────┘
#            (loop up to 3 times)
# ```

# %% [markdown]
# ## Setup: Import modules and load configuration

# %%
import sys
import os
import json
import glob
import uuid
import time
from pathlib import Path
from datetime import datetime, timedelta

# Set project_root to workspace root
current_dir = Path().resolve()
if (current_dir / "src").exists() and (current_dir / "config").exists():
    project_root = current_dir
elif (current_dir.parent / "src").exists() and (current_dir.parent / "config").exists():
    project_root = current_dir.parent
else:
    # Fallback: check SYS3DEV_ROOT env var, otherwise assume parent of notebooks/
    import os
    project_root = Path(os.environ.get("SYS3DEV_ROOT", current_dir.parent))
sys.path.insert(0, str(project_root))
print(f"project_root set to: {project_root}")

# Import modules
from src.config import load_config
from src.utils import (
    llm, TransformerEmbeddingFunction, ChatLogger, MaterialDatabase, 
    PropertyMapper, SubgraphProcessor, MaterialGrounding, Step1Cache,
    save_evaluation_export
)
from src.agents import (
    ResearchAnalyst, ResearchManager, ResearchAssistant, ResearchScientist,
    RejectedCandidateTracker, MaterialScientist, MultiAnalyst
)
from src.pipelines import (
    run_fixed_pipeline,
    run_material_discovery_pipeline,
    run_manufacturability_assessment_pipeline
)

# ChromaDB and Graph imports
from chromadb import PersistentClient
from chromadb.config import Settings
from autogen.agentchat.contrib.vectordb.chromadb import ChromaVectorDB
import networkx as nx
from sentence_transformers import SentenceTransformer
from GraphReasoning import load_embeddings

# Disable tqdm progress bars globally to prevent clutter in notebook output
os.environ['TQDM_DISABLE'] = '1'
# Also disable tqdm by monkey-patching the tqdm class
import tqdm
original_tqdm_init = tqdm.tqdm.__init__
def disabled_tqdm_init(self, *args, **kwargs):
    kwargs['disable'] = True
    return original_tqdm_init(self, *args, **kwargs)
tqdm.tqdm.__init__ = disabled_tqdm_init

# Load configuration
config = load_config()
print("✓ Configuration loaded")
# Out:
# project_root set to: /orcd/pool/004/tphage/SG_march/Sys3Dev
# ✓ Configuration loaded

# %% [markdown]
# ## Initialize LLM and Embeddings

# %%
# Initialize LLM wrapper
llm_config = {
    "api_key": config["llm"]["api_key"],
    "base_url": config["llm"]["base_url"],
    "model": config["llm"]["model_name"],
    "max_tokens": config["llm"]["max_tokens"]
}
llm_instance = llm(llm_config)
generate = llm_instance.generate_cli
print("✓ LLM wrapper initialized")

# Initialize embedding model
embedding_tokenizer = ''
embedding_model = SentenceTransformer(config["embeddings"]["model_name"], trust_remote_code=True)
embedding_function = TransformerEmbeddingFunction(
    embedding_tokenizer=embedding_tokenizer,
    embedding_model=embedding_model
)
print("✓ Embedding model initialized")
# Out:
# ✓ LLM wrapper initialized
# <All keys matched successfully>
# ✓ Embedding model initialized

# %% [markdown]
# ## Load Knowledge Graphs and Embeddings

# %%
# Load Knowledge Graphs
graphs_cfg = config["data"]["graphs"]
kg_dir = graphs_cfg["kg_dir"]

# Material Properties Knowledge Graph (used in System 1 Step 7 and System 2)
mp_cfg = graphs_cfg["material_properties"]
mp_graph_path = os.path.join(kg_dir, mp_cfg["graph_file"])
G_materialproperties = nx.read_graphml(mp_graph_path)
relation = nx.get_edge_attributes(G_materialproperties, "title")
nx.set_edge_attributes(G_materialproperties, relation, "relation")
nx.set_node_attributes(G_materialproperties, nx.pagerank(G_materialproperties), "pr")
print(f"Material Properties KG loaded: {G_materialproperties}")

# Load node embeddings for Material Properties KG
mp_embeddings_path = os.path.join(kg_dir, mp_cfg["embedding_file"])
node_embeddings_materialproperties = load_embeddings(mp_embeddings_path)
print("✓ Material Properties knowledge graph and embeddings loaded")

# PFAS Knowledge Graph (used in System 1 Step 4)
pfas_cfg = graphs_cfg["pfas"]
pfas_graph_path = os.path.join(kg_dir, pfas_cfg["graph_file"])
G_pfas = nx.read_graphml(pfas_graph_path)
relation_pfas = nx.get_edge_attributes(G_pfas, "title")
nx.set_edge_attributes(G_pfas, relation_pfas, "relation")
nx.set_node_attributes(G_pfas, nx.pagerank(G_pfas), "pr")
print(f"PFAS KG loaded: {G_pfas}")

# Load node embeddings for PFAS KG
pfas_embeddings_path = os.path.join(kg_dir, pfas_cfg["embedding_file"])
node_embeddings_pfas = load_embeddings(pfas_embeddings_path)
print("✓ PFAS knowledge graph and embeddings loaded")

# Patent Knowledge Graph (used in System 2)
patent_cfg = graphs_cfg["patents"]
patent_kg_path = os.path.join(kg_dir, patent_cfg["graph_file"])
G_patents = nx.read_graphml(patent_kg_path)
relation_patents = nx.get_edge_attributes(G_patents, "title")
nx.set_edge_attributes(G_patents, relation_patents, "relation")
nx.set_node_attributes(G_patents, nx.pagerank(G_patents), "pr")
print(f"Patent KG loaded: {G_patents}")

# Load Patent KG node embeddings
patent_embeddings_path = os.path.join(kg_dir, patent_cfg["embedding_file"])
node_embeddings_patents = load_embeddings(patent_embeddings_path)
print(f"✓ Loaded Patent KG embeddings: {len(node_embeddings_patents)} nodes")
print("✓ All knowledge graphs and embeddings loaded")
# Out:
# Material Properties KG loaded: DiGraph with 317800 nodes and 774009 edges
# ✓ Material Properties knowledge graph and embeddings loaded
# PFAS KG loaded: DiGraph with 144335 nodes and 459248 edges
# ✓ PFAS knowledge graph and embeddings loaded
# Patent KG loaded: DiGraph with 199008 nodes and 578361 edges
# ✓ Loaded Patent KG embeddings: 199008 nodes
# ✓ All knowledge graphs and embeddings loaded

# %%
# Initialize Step 1 cache to avoid re-running expensive operations in subsequent iterations
# Cache will store material grounding, KG extraction, and subgraph processing results
step1_cache = Step1Cache(enable_persistence=False)  # Set to True to persist across sessions
print("✓ Step 1 cache initialized")
cache_stats = step1_cache.get_stats()
print(f"  Cache entries: {cache_stats['memory_entries']}")
# Out:
# ✓ Step 1 cache initialized
#   Cache entries: 0

# %% [markdown]
# ## Load ChromaDB Corpora

# %%
# Connect to ChromaDB databases
chroma_cfg = config["data"]["chromadb"]
base_path = chroma_cfg.get("base_path", "")

# PFAS ChromaDB (for System 1)
pfas_cfg = chroma_cfg["pfas"]
if base_path:
    pfas_db_path = os.path.join(base_path, pfas_cfg["database_path"])
else:
    pfas_db_path = pfas_cfg["database_path"]
client_pfas = PersistentClient(path=pfas_db_path)
pfas_collection = client_pfas.get_collection(pfas_cfg["collection_name"], embedding_function=embedding_function)
ChromaDB_PFAS = ChromaVectorDB(client=client_pfas, embedding_function=embedding_function)
ChromaDB_PFAS.active_collection = pfas_collection
print("✓ PFAS ChromaDB loaded")

# Patents ChromaDB (for System 2)
patents_cfg = chroma_cfg["patents"]
if base_path:
    patents_db_path = os.path.join(base_path, patents_cfg["database_path"])
else:
    patents_db_path = patents_cfg["database_path"]
client_patents = PersistentClient(path=patents_db_path)
patents_collections = client_patents.list_collections()
patents_collection_name = patents_cfg["collection_name"] or patents_collections[0].name
patents_collection = client_patents.get_collection(patents_collection_name, embedding_function=embedding_function)
print("✓ Patents ChromaDB loaded")

# MaterialDB ChromaDB (for System 2)
materialdb_cfg = chroma_cfg["materialdb"]
if base_path:
    materialdb_db_path = os.path.join(base_path, materialdb_cfg["database_path"])
else:
    materialdb_db_path = materialdb_cfg["database_path"]
client_materialdb = PersistentClient(path=materialdb_db_path)
materialdb_collections = client_materialdb.list_collections()
materialdb_collection_name = materialdb_cfg["collection_name"] or materialdb_collections[0].name
materialdb_collection = client_materialdb.get_collection(materialdb_collection_name, embedding_function=embedding_function)
print("✓ MaterialDB ChromaDB loaded")

# Manufacturing Textbooks ChromaDB (for System 3)
manufacturing_cfg = chroma_cfg.get("manufacturing_textbooks", {})
process_analysts = {}
if manufacturing_cfg:
    try:
        mfg_db_path = os.path.join(base_path, manufacturing_cfg["database_path"]) if base_path else manufacturing_cfg["database_path"]
        if os.path.exists(mfg_db_path):
            client_mfg = PersistentClient(path=mfg_db_path)
            mfg_collections = client_mfg.list_collections()
            mfg_collection_name = manufacturing_cfg.get("collection_name") or (mfg_collections[0].name if mfg_collections else None)
            if mfg_collection_name:
                mfg_collection = client_mfg.get_collection(mfg_collection_name, embedding_function=embedding_function)
                n_results_per_source = config.get("pipelines", {}).get("manufacturability_assessment", {}).get("n_results_per_source", 5)
                process_analysts["manufacturing_textbooks"] = ResearchAnalyst(
                    collection=mfg_collection,
                    embedding_function=embedding_function,
                    n_results=n_results_per_source,
                )
                print("✓ Manufacturing Textbooks ChromaDB loaded")
    except Exception as e:
        print(f"⚠ Skipping manufacturing_textbooks: {e}")

# Spec Sheets ChromaDB (for System 3, optional)
spec_sheets_cfg = chroma_cfg.get("spec_sheets", {})
if spec_sheets_cfg:
    try:
        spec_db_path = os.path.join(base_path, spec_sheets_cfg["database_path"]) if base_path else spec_sheets_cfg["database_path"]
        if os.path.exists(spec_db_path):
            client_spec = PersistentClient(path=spec_db_path)
            spec_collections = client_spec.list_collections()
            spec_collection_name = spec_sheets_cfg.get("collection_name") or (spec_collections[0].name if spec_collections else None)
            if spec_collection_name:
                spec_collection = client_spec.get_collection(spec_collection_name, embedding_function=embedding_function)
                n_results_per_source = config.get("pipelines", {}).get("manufacturability_assessment", {}).get("n_results_per_source", 5)
                process_analysts["spec_sheets"] = ResearchAnalyst(
                    collection=spec_collection,
                    embedding_function=embedding_function,
                    n_results=n_results_per_source,
                )
                print("✓ Spec Sheets ChromaDB loaded")
    except Exception as e:
        print(f"⚠ Skipping spec_sheets: {e}")

# Add Patents and MaterialDB to process analysts for System 3
n_results_per_source = config.get("pipelines", {}).get("manufacturability_assessment", {}).get("n_results_per_source", 5)
process_analysts["patents"] = ResearchAnalyst(
    collection=patents_collection,
    embedding_function=embedding_function,
    n_results=n_results_per_source,
)
process_analysts["materialdb"] = ResearchAnalyst(
    collection=materialdb_collection,
    embedding_function=embedding_function,
    n_results=n_results_per_source,
)

# Create MultiAnalyst for System 3 process retrieval
process_analyst = MultiAnalyst(process_analysts) if process_analysts else None
print(f"✓ Process analyst initialized with {len(process_analysts)} sources: {list(process_analysts.keys())}")
# Out:
# ✓ PFAS ChromaDB loaded
# ✓ Patents ChromaDB loaded
# ✓ MaterialDB ChromaDB loaded
# ✓ Manufacturing Textbooks ChromaDB loaded
# ✓ Process analyst initialized with 3 sources: ['manufacturing_textbooks', 'patents', 'materialdb']

# %%
# Helper function to generate human-readable run_id
def generate_run_id(output_dir, prefix="system1"):
    """Generate human-readable run_id: YYYYMMDDHH_N format"""
    now = datetime.now()
    base_id = now.strftime("%Y%m%d%H")  # YYYYMMDDHH
    
    # Find existing files with same base
    pattern = os.path.join(output_dir, f"{prefix}_{base_id}_*.json")
    existing_files = glob.glob(pattern)
    
    # Extract counters and find max
    max_counter = -1
    for file in existing_files:
        filename = os.path.basename(file)
        # Extract counter from filename: prefix_YYYYMMDDHH_N.json
        parts = filename.replace(".json", "").split("_")
        if len(parts) >= 3:
            try:
                counter = int(parts[-1])
                max_counter = max(max_counter, counter)
            except ValueError:
                pass
    
    # Increment counter
    counter = max_counter + 1
    return f"{base_id}_{counter}"

# Generate base run_id for this session
output_dir = os.path.join(project_root, "pipeline_logs")
os.makedirs(output_dir, exist_ok=True)
base_run_id = generate_run_id(output_dir, prefix="system1").split("_")[0]  # Just the timestamp part
print(f"✓ Base run_id for this session: {base_run_id}")

# Initialize System 1 components
pipeline_cfg_s1 = config["pipelines"]["material_requirements"]
chat_logger_s1 = ChatLogger(
    run_id=generate_run_id(output_dir, prefix="system1"),
    pipeline="material_requirements"
)

analyst_s1 = ResearchAnalyst(
    collection=pfas_collection,
    embedding_function=embedding_function,
    n_results=pipeline_cfg_s1["n_results"],
    chat_logger=chat_logger_s1
)

manager_s1 = ResearchManager(
    name="research_manager",
    system_message=None,
    generate_fn=generate,
    chat_logger=chat_logger_s1
)

research_assistant_s1 = ResearchAssistant(
    name="research_assistant",
    system_message=None,
    generate_fn=generate,
    chat_logger=chat_logger_s1
)

# Initialize ResearchScientist with Material Properties knowledge graph only (for System 1 Step 7)
scientist_s1 = ResearchScientist(
    knowledge_graph=G_materialproperties,
    node_embeddings=node_embeddings_materialproperties,
    embedding_tokenizer=embedding_tokenizer,
    embedding_model=embedding_model,
    algorithm="shortest",
    generate_fn=generate,   # needed for LLM-based node classification in Phase 1.6
    chat_logger=chat_logger_s1
)

# Initialize PFAS ResearchScientist for querying PFAS KG during question answering (System 1 Step 4)
pfas_scientist_s1 = ResearchScientist(
    knowledge_graph=G_pfas,
    node_embeddings=node_embeddings_pfas,
    embedding_tokenizer=embedding_tokenizer,
    embedding_model=embedding_model,
    algorithm="shortest",
    chat_logger=chat_logger_s1
)

print("✓ System 1 agents initialized")

# Initialize System 2 components
pipeline_cfg_s2 = config["pipelines"]["material_discovery"]

# Create two ResearchAnalyst instances for System 2 - one for each ChromaDB
analyst_patents_s2 = ResearchAnalyst(
    collection=patents_collection,
    embedding_function=embedding_function,
    n_results=5,
    chat_logger=None  # Will be set per iteration
)

analyst_materialdb_s2 = ResearchAnalyst(
    collection=materialdb_collection,
    embedding_function=embedding_function,
    n_results=5,
    chat_logger=None  # Will be set per iteration
)

# Initialize ResearchScientist with BOTH knowledge graphs using "separate" strategy (for System 2)
scientist_s2 = ResearchScientist(
    knowledge_graph=G_materialproperties,
    node_embeddings=node_embeddings_materialproperties,
    embedding_tokenizer=embedding_tokenizer,
    embedding_model=embedding_model,
    algorithm="shortest",
    chat_logger=None,  # Will be set per iteration
    generate_fn=generate,
    # Second knowledge graph parameters
    knowledge_graph_2=G_patents,
    node_embeddings_2=node_embeddings_patents,
    kg_names=["material_properties", "patents"],
    kg_descriptions=[
        "Material properties and characteristics knowledge graph containing relationships between materials, properties, and applications",
        "Patent knowledge graph containing information about patents, materials, and related technologies"
    ],
    multi_kg_strategy="separate"
)

# Initialize new components for System 2 Step 1
property_mapper = PropertyMapper(
    embedding_model=embedding_model,
    embedding_tokenizer=embedding_tokenizer
)

# Load material database
material_db_cfg = config.get("data", {}).get("material_database", {})
material_db_path = material_db_cfg.get("path", "./data/internal_material_database.json")
material_db = MaterialDatabase.load_from_json(material_db_path, property_mapper=property_mapper)
print(f"✓ Material database loaded: {len(material_db)} materials")

# Initialize subgraph processor (uses config utils.subgraph_processor)
subgraph_processor = SubgraphProcessor(embedding_model=embedding_model)

# Initialize material grounding
material_grounding = MaterialGrounding(
    knowledge_graph=G_materialproperties,
    node_embeddings=node_embeddings_materialproperties,
    embedding_model=embedding_model,
    embedding_tokenizer=embedding_tokenizer
)

print("✓ System 2 components initialized")

# Initialize System 3 components (manager will be created per iteration with chat_logger)
print("✓ System 3 components initialized")
print("✓ All agents and components initialized")
# Out:
# ✓ Base run_id for this session: 2026031106
# ✓ System 1 agents initialized
# ✓ ResearchScientist initialized with 2 knowledge graphs: ['material_properties', 'patents']
#   Strategy: separate
#   KG Descriptions: ['Material properties and characteristics knowledge graph containing relationships between materials, properties, and applications', 'Patent knowledge graph containing information about patents, materials, and related technologies']
# ✓ Material database loaded: 20 materials
# ✓ System 2 components initialized
# ✓ System 3 components initialized
# ✓ All agents and components initialized

# %%
# Initialize shared tracker that will be used across all System 2 → System 3 iterations
# This ensures rejected candidates from System 3 are automatically avoided in subsequent System 2 runs
tracker = RejectedCandidateTracker()
print("✓ Shared RejectedCandidateTracker initialized")
print(f"  Current rejected candidates: {len(tracker.get_all_rejected())}")
# Out:
# ✓ Shared RejectedCandidateTracker initialized
#   Current rejected candidates: 0

# %%
# Initialize PipelineRun tracking object
pipeline_start_time = datetime.utcnow()
pipeline_run_id = base_run_id  # Use the base_run_id from initialization

pipeline_run = {
    "pipeline_run_id": pipeline_run_id,
    "start_time": pipeline_start_time.isoformat() + "Z",
    "end_time": None,
    "total_duration_seconds": None,
    "system1": {
        "run_id": None,
        "start_time": None,
        "end_time": None,
        "duration_seconds": None,
        "result_path": None,
        "chat_log_path": None,
        "properties_extracted": None
    },
    "system2_system3_loop": {
        "max_iterations": None,
        "total_iterations": 0,
        "iterations": []
    },
    "final_outcome": {
        "status": None,
        "final_candidate": None,
        "total_rejected_candidates": None
    }
}

print("✓ PipelineRun tracking object initialized")
print(f"  Pipeline Run ID: {pipeline_run_id}")
print(f"  Start Time: {pipeline_start_time.isoformat()}Z")
# Out:
# ✓ PipelineRun tracking object initialized
#   Pipeline Run ID: 2026031106
#   Start Time: 2026-03-11T10:13:08.897339Z

# %% [markdown]
# ## Run System 1: Property Extraction

# %%
# Define your research query
sentence = "Find a substitute material for PTFE that can be used in industrial seals applications"
material_X = "PTFE"
application_Y = "industrial seals"
keywords = [material_X, application_Y]

print("=" * 70)
print("Running System 1: Property Extraction")
print("=" * 70)
print(f"Query: {sentence}")
print(f"Material to replace (X): {material_X}")
print(f"Application (Y): {application_Y}")
print()

# Track System 1 timing
system1_start_time = datetime.utcnow()
pipeline_run["system1"]["start_time"] = system1_start_time.isoformat() + "Z"

# Run System 1 pipeline
system1_result = run_fixed_pipeline(
    sentence=sentence,
    keywords=keywords,
    analyst=analyst_s1,
    manager=manager_s1,
    research_assistant=research_assistant_s1,
    scientist=scientist_s1,  # Material Properties KG for Step 7
    pfas_scientist=pfas_scientist_s1,  # PFAS KG for Step 4 (question answering)
    include_rag_context=pipeline_cfg_s1["include_rag_context"],
    max_items=pipeline_cfg_s1["max_items"],
    temperature=config["llm"]["temperature"],
    n_results=pipeline_cfg_s1["n_results"],
    chat_logger=chat_logger_s1
)

# Track System 1 end time and duration
system1_end_time = datetime.utcnow()
system1_duration = (system1_end_time - system1_start_time).total_seconds()
pipeline_run["system1"]["end_time"] = system1_end_time.isoformat() + "Z"
pipeline_run["system1"]["duration_seconds"] = system1_duration

# Extract properties W and subgraph data
extracted_keywords = system1_result.get("extracted_keywords", []) or []
keywords_list = system1_result.get("keywords", []) or []
properties_W = {
    "required": extracted_keywords,
    "target_values": {}
}

# Extract constraints from System 1 (new: System 1 now extracts hard constraints)
extracted_constraints = system1_result.get("extracted_constraints", []) or []

# Extract subgraph data from keyword_connections for System 2
subgraph_data = None
keyword_connections = system1_result.get("keyword_connections")

if keyword_connections:
    # Serialize subgraph data for System 2
    subgraph_data = {
        "summary": keyword_connections.get("summary", {}) or {},
        "matched_node_ids": keyword_connections.get("matched_node_ids", []) or [],
        "found_paths": keyword_connections.get("found_paths", []) or [],
        "keyword_to_nodes": keyword_connections.get("keyword_to_nodes", {}) or {},
        "kg_results": keyword_connections.get("kg_results", {}) or {},
        "strategy": (keyword_connections.get("summary", {}) or {}).get("strategy", "single"),
    }

    # For connection_subgraph, serialize as node/edge lists
    connection_subgraph = keyword_connections.get("connection_subgraph")
    if connection_subgraph is not None:
        try:
            nodes = list(connection_subgraph.nodes())
            edges = list(connection_subgraph.edges())
            node_attributes = {n: dict(connection_subgraph.nodes[n]) for n in nodes}
            edge_attributes = {}
            is_multi = getattr(connection_subgraph, "is_multigraph", lambda: False)()
            if is_multi:
                for u, v, k, data in connection_subgraph.edges(keys=True, data=True):
                    edge_key = f"{u}|{v}|{k}"
                    edge_attributes[edge_key] = dict(data)
                edges = list(connection_subgraph.edges(keys=True))
            else:
                for u, v, data in connection_subgraph.edges(data=True):
                    edge_key = f"{u}|{v}"
                    edge_attributes[edge_key] = dict(data)

            subgraph_data["connection_subgraph"] = {
                "nodes": nodes,
                "edges": edges,
                "node_attributes": node_attributes,
                "edge_attributes": edge_attributes,
            }
        except Exception as e:
            print(f"Warning: Could not serialize connection_subgraph: {e}")
            subgraph_data["connection_subgraph"] = None

# Save System 1 output
timestamp = datetime.utcnow().isoformat() + "Z"
system1_run_id = chat_logger_s1.run_id
output_path = os.path.join(output_dir, f"system1_{system1_run_id}.json")

system1_payload = {
    "run_id": system1_run_id,
    "timestamp": timestamp,
    "sentence": system1_result.get("sentence"),
    "keywords": keywords_list,
    "material_X": material_X,
    "application_Y": application_Y,
    "properties_W": properties_W,
    "extracted_keywords": extracted_keywords,
    "extracted_constraints": extracted_constraints,
    "num_keywords": len(extracted_keywords),
    "num_constraints": len(extracted_constraints),
    "subgraph": subgraph_data,
    "chat_log_path": system1_result.get("chat_log_path"),
}

with open(output_path, "w", encoding="utf-8") as f:
    json.dump(system1_payload, f, indent=2, ensure_ascii=False, default=str)

# Update pipeline_run with System 1 results
pipeline_run["system1"]["run_id"] = system1_run_id
pipeline_run["system1"]["result_path"] = output_path
pipeline_run["system1"]["chat_log_path"] = system1_result.get("chat_log_path")
pipeline_run["system1"]["properties_extracted"] = len(extracted_keywords)

print(f"\n✓ System 1 complete!")
print(f"✓ Saved properties W and subgraph to {output_path}")
print(f"✓ Extracted {len(extracted_keywords)} properties")
print(f"✓ System 1 duration: {system1_duration:.2f} seconds")
# Out:
# ======================================================================
# Running System 1: Property Extraction
# ======================================================================
# Query: Find a substitute material for PTFE that can be used in industrial seals applications
# Material to replace (X): PTFE
# Application (Y): industrial seals
#
# ======================================================================
# Material Requirements Analysis: Starting Process
# ======================================================================
#
# ----------------------------------------------------------------------
# Step 1: ResearchAnalyst - Performing RAG Retrieval
# ----------------------------------------------------------------------
# → Querying ChromaDB with sentence and keywords...
# ✓ RAG retrieval complete: 0 documents retrieved
# ✗ No RAG results found, using analyze_question instead (i.e., no keywords used in retrieval)
# ✓ RAG retrieval complete: 5 documents retrieved
#   Document previews:
#     1. | Auto/Aero Fuels   Polytetrafluoroethylene (PTFE)   [10,18]  Polym oly ymers   Lubricants   [10,18]   -  Viton B: Gaskets  Auto/Aero Fuels   Lubrican...
#     2. ### 2.4. Applications Of Pfas In Modern Automobiles
#
# PFAS has been widely used in high-performance mechanical systems such as vehicle combustion engin...
#     3. Numerous PFAS have been used as processing aids, raw material, or manufacturing intermediate in fluoropolymer production. Fluoropolymers, which can be...
#
# ----------------------------------------------------------------------
# Step 2: Preparing Analysis Result for ResearchManager
# ----------------------------------------------------------------------
# ✓ Prepared analysis result with 5 RAG documents
#
# ----------------------------------------------------------------------
# Step 3: ResearchManager - Generating Research Questions
# ----------------------------------------------------------------------
# → Calling ResearchManager.process() with max_items=6, temperature=0...
# ✓ ResearchManager complete: 4 questions generated
#   Generated questions:
#     1. What chemical resistance and solvent compatibility must a substitute material exhibit to match PTFE’...
#     2. Which temperature range (including cryogenic and high‑temperature) and pressure tolerance are requir...
#     3. What mechanical properties—such as compression set, wear resistance, elasticity, and cyclic fatigue ...
#     4. Considering regulatory restrictions on PFAS and cost constraints, which material classes (e.g., fluo...
#
# ----------------------------------------------------------------------
# Step 4: Processing Questions - Collecting Information via RAG and PFAS KG
# ----------------------------------------------------------------------
# → Processing 4 questions (workers=1)...
#   [1/4] Processing: What chemical resistance and solvent compatibility must a substitute material ex...
#       ✓ Retrieved 5 documents from RAG
#       ✓ PFAS KG: Found 10 paths, 14 nodes
#   [2/4] Processing: Which temperature range (including cryogenic and high‑temperature) and pressure ...
#       ✓ Retrieved 5 documents from RAG
#       ✓ PFAS KG: Found 10 paths, 17 nodes
#   [3/4] Processing: What mechanical properties—such as compression set, wear resistance, elasticity,...
#       ✓ Retrieved 5 documents from RAG
#       ✓ PFAS KG: Found 10 paths, 12 nodes
#   [4/4] Processing: Considering regulatory restrictions on PFAS and cost constraints, which material...
#       ✓ Retrieved 5 documents from RAG
#       ✓ PFAS KG: Found 10 paths, 13 nodes
# ✓ Question processing complete: 4 questions processed
#
# ----------------------------------------------------------------------
# Step 5: ResearchManager - Answering Questions
# ----------------------------------------------------------------------
# → Answering 4 questions based on retrieved information...
#   [1/4] Answering: What chemical resistance and solvent compatibility must a substitute material ex...
#       → Including PFAS KG context in answer
#       → Evaluating if question was answered using LLM...
#       ✓ Answered (with KG) - Generated answer (3549 chars): **Key requirements for a PTFE‑like substitute in industrial sealants**
#
# | Property | What the substitute must match | Evidence from the retrieved docu...
#   [2/4] Answering: Which temperature range (including cryogenic and high‑temperature) and pressure ...
#       → Including PFAS KG context in answer
#       → Evaluating if question was answered using LLM...
#       ✗ Not answered (with KG) - Generated answer (2011 chars): **Answer**
#
# | Item | What the documents say | Source |
# |------|------------------------|--------|
# | **Cryogenic tolerance of PTFE seals** | The retrie...
#   [3/4] Answering: What mechanical properties—such as compression set, wear resistance, elasticity,...
#       → Including PFAS KG context in answer
#       → Evaluating if question was answered using LLM...
#       ✓ Answered (with KG) - Generated answer (3455 chars): **Critical mechanical properties for PTFE‑based seals**
#
# | Property | Why it matters for sealing | What the retrieved documents say |
# |----------|----...
#   [4/4] Answering: Considering regulatory restrictions on PFAS and cost constraints, which material...
#       → Including PFAS KG context in answer
#       → Evaluating if question was answered using LLM...
#       ✓ Answered (with KG) - Generated answer (3566 chars): **Viable material classes that can be manufactured at scale while avoiding PFAS‑related restrictions**
#
# | Material class | Why it is viable (regulator...
# ✓ Question answering complete: 4 questions answered
#
# ----------------------------------------------------------------------
# Step 6: ResearchAssistant - Extracting Material Property Keywords
# ----------------------------------------------------------------------
# → Extracting keywords from original question and 3 answered questions...
#   → Cleaned 1 formatting artifacts from keywords
# ✓ Extracted 41 keywords/key phrases
#   Sample keywords: Key material properties & requirements for a PTFE‑substitute seal, Chemical resistance – strong acids, Chemical resistance – strong bases, Chemical resistance – oxidizers, Solvent compatibility – alkanes...
#
# ----------------------------------------------------------------------
# Step 6b: ResearchAssistant - Extracting Hard Constraints
# ----------------------------------------------------------------------
# → Extracting constraints from original question and 3 answered questions...
# ✓ Extracted 16 hard constraints
#   1. Hard Constraints for a PTFE‑substitute used in industrial seal applications
#   2. Acid & base resistance – Must remain chemically inert (no measurable swelling, degradation or loss of mechanical integrity) when exposed to strong acids (e.g., ≥ 10 % HCl, 10 % H₂SO₄) and strong bases (e.g., ≥ 10 % NaOH, 10 % KOH) at service temperatures up to 200 °C.
#   3. Oxidizer resistance – Must not degrade or lose sealing performance when exposed to common oxidizing agents (e.g., H₂O₂, O₃, Cl₂) at temperatures ≤ 200 °C.
#   4. Organic solvent compatibility – Must exhibit no measurable swelling, degradation, or dimensional change in the following solvents under typical exposure conditions: alkanes, aromatics, chlorinated hydrocarbons, ketones, esters, alcohols, and polar aprotic solvents (e.g., DMF, DMSO).
#   5. Dimensional stability – Must maintain dimensional changes ≤ 10 % when exposed to the chemicals above at temperatures up to 200 °C.
#   ... and 11 more
#
# ----------------------------------------------------------------------
# Step 7: ResearchScientist - Finding Connections Between Keywords
# ----------------------------------------------------------------------
# → Finding connections between 41 keywords in knowledge graph...
# ✓ Connections found: 366 nodes, 3070 edges
#   Algorithm used: shortest
#
# ======================================================================
# Material Requirements Analysis: Process Complete
# ======================================================================
# Summary:
#   - RAG documents retrieved: 5
#   - Questions generated: 4
#   - Questions processed: 4
#   - Questions answered: 4
#   - Keywords extracted: 41
#   - Keyword connections: 366 nodes, 3070 edges
# ======================================================================
#
#
# ✓ System 1 complete!
# ✓ Saved properties W and subgraph to /orcd/pool/004/tphage/SG_march/Sys3Dev/pipeline_logs/system1_2026031106_0.json
# ✓ Extracted 41 properties
# ✓ System 1 duration: 558.29 seconds

# %%
# Initialize loop variables
max_iterations = 3
iteration = 0
all_iterations = []  # Track all iterations for summary
# Constraints from System 1 (extracted hard constraints + any user-specified ones)
constraints_U = list(extracted_constraints)  # populated by System 1's extract_constraints step
print(f"✓ Constraints from System 1: {len(constraints_U)}")
if constraints_U:
    for i, c in enumerate(constraints_U[:5], 1):
        print(f"  {i}. {c}")
    if len(constraints_U) > 5:
        print(f"  ... and {len(constraints_U) - 5} more")

# Cache for Step 1 result from first iteration (to avoid re-running expensive operations)
cached_substitution_result = None

# Extract base run_id from System 1
system1_run_id_base = system1_run_id.split("_")[0] if "_" in system1_run_id else system1_run_id

# Initialize pipeline_run loop metadata
pipeline_run["system2_system3_loop"]["max_iterations"] = max_iterations

print("=" * 70)
print("Starting System 2 → System 3 Loop")
print("=" * 70)
print(f"Max iterations: {max_iterations}")
print(f"Base run_id: {system1_run_id_base}")
print()

while iteration < max_iterations:
    iteration += 1
    print("\n" + "=" * 70)
    print(f"Iteration {iteration}/{max_iterations}")
    print("=" * 70)
    
    # Generate run_id for this iteration
    pattern_s2 = os.path.join(output_dir, f"system2_{system1_run_id_base}_*.json")
    existing_s2 = glob.glob(pattern_s2)
    max_counter_s2 = -1
    for f in existing_s2:
        try:
            n = int(os.path.basename(f).replace(".json", "").split("_")[-1])
            max_counter_s2 = max(max_counter_s2, n)
        except (ValueError, IndexError):
            pass
    system2_counter = max_counter_s2 + 1
    system2_run_id = f"{system1_run_id_base}_{system2_counter}"
    
    # Create chat logger for System 2
    chat_logger_s2 = ChatLogger(
        run_id=system2_run_id,
        pipeline="material_discovery"
    )
    
    # Update System 2 agents with chat logger
    analyst_patents_s2.chat_logger = chat_logger_s2
    analyst_materialdb_s2.chat_logger = chat_logger_s2
    scientist_s2.chat_logger = chat_logger_s2
    
    # Create MultiAnalyst wrapper for System 2
    analyst_s2 = MultiAnalyst({
        "patents": analyst_patents_s2,
        "materialdb": analyst_materialdb_s2
    })
    
    # Create manager for System 2
    manager_s2 = ResearchManager(
        name="research_manager",
        system_message=None,
        generate_fn=generate,
        chat_logger=chat_logger_s2
    )
    
    # Create MaterialScientist for System 2
    material_scientist_s2 = MaterialScientist(
        material_db=material_db,
        knowledge_graph=G_materialproperties,
        analyst=analyst_s2,
        manager=manager_s2,
        embedding_model=embedding_model,
        embedding_tokenizer=embedding_tokenizer
    )
    
    print(f"\n--- Running System 2 (run_id: {system2_run_id}) ---")
    
    # Track System 2 timing
    system2_start_time = datetime.utcnow()
    
    # Run System 2
    system2_result = run_material_discovery_pipeline(
        material_X=material_X,
        application_Y=application_Y,
        properties_W=properties_W,
        constraints_U=constraints_U,
        analyst=analyst_s2,
        manager=manager_s2,
        scientist=scientist_s2,
        tracker=tracker,  # Shared tracker - will avoid previously rejected candidates
        max_iterations=pipeline_cfg_s2["max_iterations"],
        temperature=config["llm"]["temperature"],
        chat_logger=chat_logger_s2,
        subgraph_data=subgraph_data,
        material_db=material_db,
        subgraph_processor=subgraph_processor,
        material_grounding=material_grounding,
        material_scientist=material_scientist_s2,
        knowledge_graph=G_materialproperties,
        substitution_result=cached_substitution_result  # Use cached Step 1 result if available
    )
    
    # Track System 2 end time and duration
    system2_end_time = datetime.utcnow()
    system2_duration = (system2_end_time - system2_start_time).total_seconds()
    
    # Extract internal iteration timing from System 2
    internal_iterations = []
    iteration_history = system2_result.get("iteration_history", [])
    if iteration_history and system2_result.get("chat_log_path"):
        # Try to get timing from chat log
        try:
            with open(system2_result.get("chat_log_path"), "r") as f:
                chat_log = json.load(f)
            chat_start = datetime.fromisoformat(chat_log.get("timestamp", "").replace("Z", "+00:00"))
            interactions = chat_log.get("interactions", [])
            
            # Group interactions by iteration (approximate)
            # This is a simplified approach - in practice, you might need more sophisticated parsing
            for i, hist_item in enumerate(iteration_history):
                iter_num = hist_item.get("iteration", i + 1)
                candidate = hist_item.get("candidate", {}).get("material_name", "Unknown")
                status = "accepted" if hist_item.get("feasible") else "rejected"
                
                # Approximate timing - use chat log start + proportional time
                # This is a rough estimate; for precise timing, you'd need timestamps in iteration_history
                if len(iteration_history) > 0:
                    iter_start_offset = (system2_duration / len(iteration_history)) * (iter_num - 1)
                    iter_end_offset = (system2_duration / len(iteration_history)) * iter_num
                    iter_start = system2_start_time + timedelta(seconds=iter_start_offset)
                    iter_end = system2_start_time + timedelta(seconds=iter_end_offset)
                else:
                    iter_start = system2_start_time
                    iter_end = system2_end_time
                
                internal_iterations.append({
                    "iteration": iter_num,
                    "start_time": iter_start.isoformat() + "Z",
                    "end_time": iter_end.isoformat() + "Z",
                    "duration_seconds": (iter_end - iter_start).total_seconds(),
                    "candidate": candidate,
                    "status": status
                })
        except Exception as e:
            print(f"Warning: Could not extract internal iteration timing: {e}")
    
    # Save System 2 result
    timestamp_s2 = datetime.utcnow().isoformat() + "Z"
    system2_output_path = os.path.join(output_dir, f"system2_{system2_run_id}.json")
    
    discovery_payload = {
        "run_id": system2_run_id,
        "timestamp": timestamp_s2,
        "application": application_Y,
        "properties": properties_W,
        "constraints": constraints_U,
        "success": system2_result.get("success", False),
        "candidate": system2_result.get("candidate"),
        "iterations": system2_result.get("iterations", 0),
        "rejected_candidates": system2_result.get("rejected_candidates", []),
        "final_constraints": system2_result.get("final_constraints", []),
        "evidence_summary": system2_result.get("evidence_summary", {}),
        "iteration_history": system2_result.get("iteration_history", []),
        "property_mapping": system2_result.get("property_mapping", {}),
        "chat_log_path": system2_result.get("chat_log_path")
    }
    
    with open(system2_output_path, "w") as f:
        json.dump(discovery_payload, f, indent=2)
    
    print(f"✓ System 2 complete - saved to {system2_output_path}")
    print(f"✓ System 2 duration: {system2_duration:.2f} seconds")
    
    # Cache Step 1 result from first iteration for reuse in subsequent iterations
    if iteration == 1 and cached_substitution_result is None:
        cached_substitution_result = system2_result.get("substitution_result")
        if cached_substitution_result:
            print(f"✓ Cached Step 1 result for reuse in subsequent iterations")
    
    if not system2_result.get("success"):
        print(f"✗ System 2 failed to find a candidate material")
        all_iterations.append({
            "iteration": iteration,
            "system2_run_id": system2_run_id,
            "system2_success": False,
            "system3_run_id": None,
            "system3_status": None
        })
        break
    
    candidate_name = system2_result.get("candidate", {}).get("material_name", "Unknown")
    print(f"✓ System 2 found candidate: {candidate_name}")
    
    # Track System 3 timing
    system3_start_time = datetime.utcnow()
    
    # Generate run_id for System 3
    pattern_s3 = os.path.join(output_dir, f"system3_{system1_run_id_base}_*.json")
    existing_s3 = glob.glob(pattern_s3)
    max_counter_s3 = -1
    for f in existing_s3:
        try:
            n = int(os.path.basename(f).replace(".json", "").split("_")[-1])
            max_counter_s3 = max(max_counter_s3, n)
        except (ValueError, IndexError):
            pass
    system3_counter = max_counter_s3 + 1
    system3_run_id = f"{system1_run_id_base}_{system3_counter}"
    
    # Create chat logger for System 3
    chat_logger_s3 = ChatLogger(
        run_id=system3_run_id,
        pipeline="manufacturability_assessment"
    )
    
    # Create manager for System 3
    manager_s3 = ResearchManager(
        name="research_manager",
        system_message=None,
        generate_fn=generate,
        chat_logger=chat_logger_s3
    )
    
    print(f"\n--- Running System 3 (run_id: {system3_run_id}) ---")
    
    # Run System 3
    system3_result = run_manufacturability_assessment_pipeline(
        system2_result=system2_result,
        initial_query=sentence,
        material_X=material_X,
        application_Y=application_Y,
        constraints_U=constraints_U,
        tracker=tracker,  # Shared tracker - System 3 will add rejections here
        process_analyst=process_analyst,
        manager=manager_s3,
        properties_W=properties_W,
        config=config,
        temperature=0,
        chat_logger=chat_logger_s3,
    )
    
    # Track System 3 end time and duration
    system3_end_time = datetime.utcnow()
    system3_duration = (system3_end_time - system3_start_time).total_seconds()
    
    # Save System 3 result
    timestamp_s3 = datetime.utcnow().isoformat() + "Z"
    system3_output_path = os.path.join(output_dir, f"system3_{system3_run_id}.json")
    
    with open(system3_output_path, "w", encoding="utf-8") as f:
        system3_result["run_id"] = system3_run_id
        json.dump(system3_result, f, indent=2, default=str)
    
    print(f"✓ System 3 complete - saved to {system3_output_path}")
    print(f"✓ System 3 duration: {system3_duration:.2f} seconds")
    
    # Check status
    status = system3_result.get("status", "")
    manufacturable = system3_result.get("manufacturable", False)
    
    print(f"\nSystem 3 Status: {status.upper()}")
    
    # Record iteration in all_iterations
    all_iterations.append({
        "iteration": iteration,
        "system2_run_id": system2_run_id,
        "system2_success": True,
        "candidate": candidate_name,
        "system3_run_id": system3_run_id,
        "system3_status": status,
        "manufacturable": manufacturable
    })
    
    # Record iteration in pipeline_run
    iteration_data = {
        "iteration": iteration,
        "system2": {
            "run_id": system2_run_id,
            "start_time": system2_start_time.isoformat() + "Z",
            "end_time": system2_end_time.isoformat() + "Z",
            "duration_seconds": system2_duration,
            "result_path": system2_output_path,
            "chat_log_path": system2_result.get("chat_log_path"),
            "candidate": candidate_name,
            "internal_iterations": internal_iterations
        },
        "system3": {
            "run_id": system3_run_id,
            "start_time": system3_start_time.isoformat() + "Z",
            "end_time": system3_end_time.isoformat() + "Z",
            "duration_seconds": system3_duration,
            "result_path": system3_output_path,
            "chat_log_path": system3_result.get("chat_log_path"),
            "status": status,
            "blocking_constraints": system3_result.get("blocking_constraints", []),
            "feedback_to_system2": system3_result.get("feedback_to_system2", "")
        }
    }
    pipeline_run["system2_system3_loop"]["iterations"].append(iteration_data)
    pipeline_run["system2_system3_loop"]["total_iterations"] = len(pipeline_run["system2_system3_loop"]["iterations"])
    
    # Check if manufacturable - if so, break loop
    if status == "manufacturable":
        print("\n" + "=" * 70)
        print("✓ SUCCESS: Found manufacturable candidate!")
        print("=" * 70)
        break
    
    # If blocked, continue to next iteration
    if status == "blocked":
        feedback = system3_result.get("feedback_to_system2", "")
        print(f"\n✗ Candidate rejected (blocked)")
        print(f"Feedback to System 2: {feedback[:200]}...")
        print(f"Tracker updated - rejected candidates: {len(tracker.get_all_rejected())}")

        # Persist structured System 3 feedback history for auditability.
        feedback_history = pipeline_run["system2_system3_loop"].setdefault("system3_feedback_history", [])
        blocking = system3_result.get("blocking_constraints", [])
        feedback_history.append({
            "iteration": iteration,
            "system3_run_id": system3_run_id,
            "blocking_constraints": blocking,
            "feedback_to_system2": feedback,
        })

        # Compact + deduplicate feedback before feeding it to the next System 2 iteration.
        existing_constraints_norm = {str(c).strip().lower() for c in constraints_U if str(c).strip()}
        compact_constraints = []
        for bc in blocking:
            if isinstance(bc, dict):
                ctype = str(bc.get("type", "missing_critical_info")).strip()
                desc = str(bc.get("description", "")).strip()
            else:
                ctype = "missing_critical_info"
                desc = str(bc).strip()
            if not desc:
                continue
            compact = f"S3[{ctype}]: {desc[:220]}"
            if compact.lower() not in existing_constraints_norm:
                compact_constraints.append(compact)
                existing_constraints_norm.add(compact.lower())

        if feedback:
            feedback_compact = f"S3 feedback: {feedback[:220]}"
            if feedback_compact.lower() not in existing_constraints_norm:
                compact_constraints.append(feedback_compact)
                existing_constraints_norm.add(feedback_compact.lower())

        constraints_U.extend(compact_constraints)
        print(f"  → Added {len(compact_constraints)} compact System 3 constraints")
        print(f"  → Updated constraints_U: {len(constraints_U)} total constraints")

        if iteration < max_iterations:
            print(f"\n→ Looping back to System 2 for iteration {iteration + 1}...")
        else:
            print(f"\n→ Max iterations ({max_iterations}) reached")

print("\n" + "=" * 70)
print("System 2 → System 3 Loop Complete")
print("=" * 70)
print(f"Total iterations: {len(all_iterations)}")
print(f"Final status: {all_iterations[-1]['system3_status'] if all_iterations else 'N/A'}")
# Out:
# ✓ Constraints from System 1: 16
#   1. Hard Constraints for a PTFE‑substitute used in industrial seal applications
#   2. Acid & base resistance – Must remain chemically inert (no measurable swelling, degradation or loss of mechanical integrity) when exposed to strong acids (e.g., ≥ 10 % HCl, 10 % H₂SO₄) and strong bases (e.g., ≥ 10 % NaOH, 10 % KOH) at service temperatures up to 200 °C.
#   3. Oxidizer resistance – Must not degrade or lose sealing performance when exposed to common oxidizing agents (e.g., H₂O₂, O₃, Cl₂) at temperatures ≤ 200 °C.
#   4. Organic solvent compatibility – Must exhibit no measurable swelling, degradation, or dimensional change in the following solvents under typical exposure conditions: alkanes, aromatics, chlorinated hydrocarbons, ketones, esters, alcohols, and polar aprotic solvents (e.g., DMF, DMSO).
#   5. Dimensional stability – Must maintain dimensional changes ≤ 10 % when exposed to the chemicals above at temperatures up to 200 °C.
#   ... and 11 more
# ======================================================================
# Starting System 2 → System 3 Loop
# ======================================================================
# Max iterations: 3
# Base run_id: 2026031106
#
#
# ======================================================================
# Iteration 1/3
# ======================================================================
#
# --- Running System 2 (run_id: 2026031106_0) ---
# ======================================================================
# Material Discovery Pipeline: Starting Process
# ======================================================================
#
# Pipeline Configuration:
#   [OK] Agents verified
#   [OK] Material to replace (X): PTFE
#   [OK] Application (Y): industrial seals
#   [OK] Required Properties: ['Key material properties & requirements for a PTFE‑substitute seal', 'Chemical resistance – strong acids', 'Chemical resistance – strong bases', 'Chemical resistance – oxidizers', 'Solvent compatibility – alkanes', 'Solvent compatibility – aromatics', 'Solvent compatibility – chlorinated hydrocarbons', 'Solvent compatibility – ketones', 'Solvent compatibility – esters', 'Solvent compatibility – alcohols', 'Solvent compatibility – polar aprotic solvents', 'Temperature range – up to 250\u202f°C', 'Temperature range – cryogenic flexibility (–150\u202f°C)', 'Mechanical integrity – high hardness', 'Mechanical integrity – wear resistance', 'Mechanical integrity – low moisture absorption (<0.01\u202f%)', 'Permeability – ≤10⁻¹⁰\u202fcm²/s for water', 'Compression set – <10\u202f% after 1000\u202fh', 'Coefficient of friction – ≤0.13', 'Wear volume – ≤10⁻⁶\u202fmm³/N·m', 'Elasticity – high flexibility', 'Elastic recovery – minimal permanent set', 'Cyclic fatigue life – >10⁶ cycles', 'Regulatory compliance – PFAS‑free or exempt', 'Cost – competitive at industrial scale', 'Scalability – large‑volume manufacturing', 'Low‑hazard PLC criteria – high MW (>1000\u202fDa)', 'Low‑hazard PLC criteria – negligible oligomers', 'Low‑hazard PLC criteria – low solubility', 'Dimensional stability – in aggressive solvents', 'Barrier properties – gas & liquid impermeability', 'Thermal stability – melt‑processable (ECTFE/PCTFE)', 'Chemical inertness – to fluorinated hydrocarbons', 'Mechanical durability – under pressure cycles', 'Seal geometry retention – during compression', 'Compatibility – with metal substrates (cast iron, aluminum)', 'Tribological performance – low wear against metals', 'Flexibility at low temperatures – maintain seal integrity', 'Resistance to plasticizers – avoid swelling', 'Non‑toxic – minimal leaching', 'Recyclability – or end‑of‑life considerations']
#   [OK] Constraints: 17 constraint(s)
#       - Cannot propose PFAS (per- and polyfluoroalkyl substances) materials - materials containing carbon-fluorine bonds are not allowed
#       - Hard Constraints for a PTFE‑substitute used in industrial seal applications
#       - Acid & base resistance – Must remain chemically inert (no measurable swelling, degradation or loss of mechanical integrity) when exposed to strong acids (e.g., ≥ 10 % HCl, 10 % H₂SO₄) and strong bases (e.g., ≥ 10 % NaOH, 10 % KOH) at service temperatures up to 200 °C.
#       - Oxidizer resistance – Must not degrade or lose sealing performance when exposed to common oxidizing agents (e.g., H₂O₂, O₃, Cl₂) at temperatures ≤ 200 °C.
#       - Organic solvent compatibility – Must exhibit no measurable swelling, degradation, or dimensional change in the following solvents under typical exposure conditions: alkanes, aromatics, chlorinated hydrocarbons, ketones, esters, alcohols, and polar aprotic solvents (e.g., DMF, DMSO).
#       - Dimensional stability – Must maintain dimensional changes ≤ 10 % when exposed to the chemicals above at temperatures up to 200 °C.
#       - Water‑vapor permeability – Must have a water‑vapour transmission rate ≤ 1 × 10⁻¹⁰ cm²/s (at 25 °C, 0 % RH).
#       - Temperature range – Must support continuous service from –150 °C to 250 °C without loss of sealing performance or mechanical integrity.
#       - Low‑temperature flexibility – Must remain flexible and non‑brittle down to –150 °C (i.e., no cracking or loss of elasticity at that temperature).
#       - Compression set – After 1,000 h exposure at an elevated temperature (≥ 200 °C), the material’s compression set must be < 10 %.
#       - Coefficient of friction – Under sliding contact with typical metal surfaces (e.g., steel, aluminum) the coefficient of friction must not exceed 0.13.
#       - Wear volume – The wear volume under comparable tribological testing conditions must be ≤ 1 × 10⁻⁶ mm³/N·m.
#       - Cyclic fatigue life – Must sustain ≥ 1 000 000 (10⁶) compression‑relaxation cycles at standard loading and temperature without crack initiation or propagation.
#       - PFAS exclusion – The material must contain no per‑ or polyfluoroalkyl substances (PFAS); any fluorinated content must be limited to non‑PFAS fluoropolymers that meet regulatory definitions of “low‑concern” polymers.
#       - Moisture absorption – Must absorb ≤ 0.01 % by weight when exposed to ambient humidity for 24 h.
#       - Regulatory compliance (if applicable) – If the seal is intended for use in medical or food‑contact applications, the material must be compliant with FDA 21 CFR Part 820 and relevant ISO/ASTM standards for biocompatibility and food safety.
#       - Violation of any one of these constraints would render a candidate material unsuitable as a PTFE substitute for industrial seal applications.
#   [OK] Max iterations: 5
#   [OK] Temperature: 0
#
# ======================================================================
# Step 1: Material Substitution
# ======================================================================
# → Cache miss - running Step 1 operations...
#
# ======================================================================
# Step 1: Material Substitution (Re-engineered)
# ======================================================================
#
# Input Parameters:
#   Material to replace (X): PTFE
#   Application (Y): industrial seals
#   Required Properties: ['Key material properties & requirements for a PTFE‑substitute seal', 'Chemical resistance – strong acids', 'Chemical resistance – strong bases', 'Chemical resistance – oxidizers', 'Solvent compatibility – alkanes', 'Solvent compatibility – aromatics', 'Solvent compatibility – chlorinated hydrocarbons', 'Solvent compatibility – ketones', 'Solvent compatibility – esters', 'Solvent compatibility – alcohols', 'Solvent compatibility – polar aprotic solvents', 'Temperature range – up to 250\u202f°C', 'Temperature range – cryogenic flexibility (–150\u202f°C)', 'Mechanical integrity – high hardness', 'Mechanical integrity – wear resistance', 'Mechanical integrity – low moisture absorption (<0.01\u202f%)', 'Permeability – ≤10⁻¹⁰\u202fcm²/s for water', 'Compression set – <10\u202f% after 1000\u202fh', 'Coefficient of friction – ≤0.13', 'Wear volume – ≤10⁻⁶\u202fmm³/N·m', 'Elasticity – high flexibility', 'Elastic recovery – minimal permanent set', 'Cyclic fatigue life – >10⁶ cycles', 'Regulatory compliance – PFAS‑free or exempt', 'Cost – competitive at industrial scale', 'Scalability – large‑volume manufacturing', 'Low‑hazard PLC criteria – high MW (>1000\u202fDa)', 'Low‑hazard PLC criteria – negligible oligomers', 'Low‑hazard PLC criteria – low solubility', 'Dimensional stability – in aggressive solvents', 'Barrier properties – gas & liquid impermeability', 'Thermal stability – melt‑processable (ECTFE/PCTFE)', 'Chemical inertness – to fluorinated hydrocarbons', 'Mechanical durability – under pressure cycles', 'Seal geometry retention – during compression', 'Compatibility – with metal substrates (cast iron, aluminum)', 'Tribological performance – low wear against metals', 'Flexibility at low temperatures – maintain seal integrity', 'Resistance to plasticizers – avoid swelling', 'Non‑toxic – minimal leaching', 'Recyclability – or end‑of‑life considerations']
#   Constraints: 17 constraint(s)
#     - Cannot propose PFAS (per- and polyfluoroalkyl substances) materials - materials containing carbon-fluorine bonds are not allowed
#     - Hard Constraints for a PTFE‑substitute used in industrial seal applications
#     - Acid & base resistance – Must remain chemically inert (no measurable swelling, degradation or loss of mechanical integrity) when exposed to strong acids (e.g., ≥ 10 % HCl, 10 % H₂SO₄) and strong bases (e.g., ≥ 10 % NaOH, 10 % KOH) at service temperatures up to 200 °C.
#     - Oxidizer resistance – Must not degrade or lose sealing performance when exposed to common oxidizing agents (e.g., H₂O₂, O₃, Cl₂) at temperatures ≤ 200 °C.
#     - Organic solvent compatibility – Must exhibit no measurable swelling, degradation, or dimensional change in the following solvents under typical exposure conditions: alkanes, aromatics, chlorinated hydrocarbons, ketones, esters, alcohols, and polar aprotic solvents (e.g., DMF, DMSO).
#     - Dimensional stability – Must maintain dimensional changes ≤ 10 % when exposed to the chemicals above at temperatures up to 200 °C.
#     - Water‑vapor permeability – Must have a water‑vapour transmission rate ≤ 1 × 10⁻¹⁰ cm²/s (at 25 °C, 0 % RH).
#     - Temperature range – Must support continuous service from –150 °C to 250 °C without loss of sealing performance or mechanical integrity.
#     - Low‑temperature flexibility – Must remain flexible and non‑brittle down to –150 °C (i.e., no cracking or loss of elasticity at that temperature).
#     - Compression set – After 1,000 h exposure at an elevated temperature (≥ 200 °C), the material’s compression set must be < 10 %.
#     - Coefficient of friction – Under sliding contact with typical metal surfaces (e.g., steel, aluminum) the coefficient of friction must not exceed 0.13.
#     - Wear volume – The wear volume under comparable tribological testing conditions must be ≤ 1 × 10⁻⁶ mm³/N·m.
#     - Cyclic fatigue life – Must sustain ≥ 1 000 000 (10⁶) compression‑relaxation cycles at standard loading and temperature without crack initiation or propagation.
#     - PFAS exclusion – The material must contain no per‑ or polyfluoroalkyl substances (PFAS); any fluorinated content must be limited to non‑PFAS fluoropolymers that meet regulatory definitions of “low‑concern” polymers.
#     - Moisture absorption – Must absorb ≤ 0.01 % by weight when exposed to ambient humidity for 24 h.
#     - Regulatory compliance (if applicable) – If the seal is intended for use in medical or food‑contact applications, the material must be compliant with FDA 21 CFR Part 820 and relevant ISO/ASTM standards for biocompatibility and food safety.
#     - Violation of any one of these constraints would render a candidate material unsuitable as a PTFE substitute for industrial seal applications.
#   Temperature: 0
#   Knowledge Graph: 317800 nodes, 774009 edges
#   Material Database: 20 materials
#
# ----------------------------------------------------------------------
# Phase 1.1: Load and Filter Subgraph from System 1
# ----------------------------------------------------------------------
# → Loading subgraph from System 1...
#   → Subgraph data keys: ['summary', 'matched_node_ids', 'found_paths', 'keyword_to_nodes', 'kg_results', 'strategy', 'connection_subgraph']
#   → Matched node IDs in data: 41
#   → Found paths in data: 780
#   [OK] Loaded subgraph: 366 nodes, 3070 edges
#
# → Filtering subgraph by relevance...
#   → Application context: industrial seals
#   → Required properties: ['Key material properties & requirements for a PTFE‑substitute seal', 'Chemical resistance – strong acids', 'Chemical resistance – strong bases', 'Chemical resistance – oxidizers', 'Solvent compatibility – alkanes', 'Solvent compatibility – aromatics', 'Solvent compatibility – chlorinated hydrocarbons', 'Solvent compatibility – ketones', 'Solvent compatibility – esters', 'Solvent compatibility – alcohols', 'Solvent compatibility – polar aprotic solvents', 'Temperature range – up to 250\u202f°C', 'Temperature range – cryogenic flexibility (–150\u202f°C)', 'Mechanical integrity – high hardness', 'Mechanical integrity – wear resistance', 'Mechanical integrity – low moisture absorption (<0.01\u202f%)', 'Permeability – ≤10⁻¹⁰\u202fcm²/s for water', 'Compression set – <10\u202f% after 1000\u202fh', 'Coefficient of friction – ≤0.13', 'Wear volume – ≤10⁻⁶\u202fmm³/N·m', 'Elasticity – high flexibility', 'Elastic recovery – minimal permanent set', 'Cyclic fatigue life – >10⁶ cycles', 'Regulatory compliance – PFAS‑free or exempt', 'Cost – competitive at industrial scale', 'Scalability – large‑volume manufacturing', 'Low‑hazard PLC criteria – high MW (>1000\u202fDa)', 'Low‑hazard PLC criteria – negligible oligomers', 'Low‑hazard PLC criteria – low solubility', 'Dimensional stability – in aggressive solvents', 'Barrier properties – gas & liquid impermeability', 'Thermal stability – melt‑processable (ECTFE/PCTFE)', 'Chemical inertness – to fluorinated hydrocarbons', 'Mechanical durability – under pressure cycles', 'Seal geometry retention – during compression', 'Compatibility – with metal substrates (cast iron, aluminum)', 'Tribological performance – low wear against metals', 'Flexibility at low temperatures – maintain seal integrity', 'Resistance to plasticizers – avoid swelling', 'Non‑toxic – minimal leaching', 'Recyclability – or end‑of‑life considerations']
#   → Constraints: ['Cannot propose PFAS (per- and polyfluoroalkyl substances) materials - materials containing carbon-fluorine bonds are not allowed', 'Hard Constraints for a PTFE‑substitute used in industrial seal applications', 'Acid & base resistance – Must remain chemically inert (no measurable swelling, degradation or loss of mechanical integrity) when exposed to strong acids (e.g., ≥\u202f10\u202f% HCl, 10\u202f% H₂SO₄) and strong bases (e.g., ≥\u202f10\u202f% NaOH, 10\u202f% KOH) at service temperatures up to 200\u202f°C.', 'Oxidizer resistance – Must not degrade or lose sealing performance when exposed to common oxidizing agents (e.g., H₂O₂, O₃, Cl₂) at temperatures ≤\u202f200\u202f°C.', 'Organic solvent compatibility – Must exhibit no measurable swelling, degradation, or dimensional change in the following solvents under typical exposure conditions: alkanes, aromatics, chlorinated hydrocarbons, ketones, esters, alcohols, and polar aprotic solvents (e.g., DMF, DMSO).', 'Dimensional stability – Must maintain dimensional changes ≤\u202f10\u202f% when exposed to the chemicals above at temperatures up to 200\u202f°C.', 'Water‑vapor permeability – Must have a water‑vapour transmission rate ≤\u202f1\u202f×\u202f10⁻¹⁰\u202fcm²/s (at 25\u202f°C, 0\u202f% RH).', 'Temperature range – Must support continuous service from –150\u202f°C to 250\u202f°C without loss of sealing performance or mechanical integrity.', 'Low‑temperature flexibility – Must remain flexible and non‑brittle down to –150\u202f°C (i.e., no cracking or loss of elasticity at that temperature).', 'Compression set – After 1,000\u202fh exposure at an elevated temperature (≥\u202f200\u202f°C), the material’s compression set must be <\u202f10\u202f%.', 'Coefficient of friction – Under sliding contact with typical metal surfaces (e.g., steel, aluminum) the coefficient of friction must not exceed 0.13.', 'Wear volume – The wear volume under comparable tribological testing conditions must be ≤\u202f1\u202f×\u202f10⁻⁶\u202fmm³/N·m.', 'Cyclic fatigue life – Must sustain ≥\u202f1\u202f000\u202f000 (10⁶) compression‑relaxation cycles at standard loading and temperature without crack initiation or propagation.', 'PFAS exclusion – The material must contain no per‑ or polyfluoroalkyl substances (PFAS); any fluorinated content must be limited to non‑PFAS fluoropolymers that meet regulatory definitions of “low‑concern” polymers.', 'Moisture absorption – Must absorb ≤\u202f0.01\u202f% by weight when exposed to ambient humidity for 24\u202fh.', 'Regulatory compliance (if applicable) – If the seal is intended for use in medical or food‑contact applications, the material must be compliant with FDA 21\u202fCFR Part\u202f820 and relevant ISO/ASTM standards for biocompatibility and food safety.', 'Violation of any one of these constraints would render a candidate material unsuitable as a PTFE substitute for industrial seal applications.']
#   [OK] Filtered subgraph: 239 nodes, 1806 edges
#   → Reduction: 127 nodes removed (34.7%)
#   → Reduction: 1264 edges removed (41.2%)
#
# ----------------------------------------------------------------------
# Phase 1.2: Ground Lab Materials in Knowledge Graph
# ----------------------------------------------------------------------
# → Grounding lab materials in knowledge graph...
#   → Material database contains 20 materials
#   → Sample materials in database: AKROTEK® PEEK 8 natural (7343) (Dry) (akro-plastic-gmbh-akrotek-peek-8-natural-7343-dry), RILSAN® BMNO (arkema-inc-rilsan-bmno), EdgetekTM PK-000/000 (avient-corporation-edgetektm-pk-000000), KEBAPEAK PEEK XS1300 (barlog-plastics-kebapeak-peek-xs1300), FORTRON® PPS POLYPHENYLENE SULFIDE (PPS) (celanese-fortron-pps-polyphenylene-sulfide-pps)
#   [OK] Grounded 20 materials
#   → Sample grounded materials: akro-plastic-gmbh-akrotek-peek-8-natural-7343-dry, arkema-inc-rilsan-bmno, avient-corporation-edgetektm-pk-000000, barlog-plastics-kebapeak-peek-xs1300, celanese-fortron-pps-polyphenylene-sulfide-pps
#
#   Grounding Details (sample):
#     - akro-plastic-gmbh-akrotek-peek-8-natural-7343-dry:
#       → Found 1 matching nodes in KG
#         1. Node: Poly-ether-ether-ketone (PEEK) (similarity: 0.657)
#     - arkema-inc-rilsan-bmno:
#       → Found 1 matching nodes in KG
#         1. Node: BMPN (similarity: 0.685)
#     - avient-corporation-edgetektm-pk-000000:
#       → Found 1 matching nodes in KG
#         1. Node: EdgeTaper Platinum (similarity: 0.687)
#
# ----------------------------------------------------------------------
# Phase 1.3: Retrieve Material-Property Relationships
# ----------------------------------------------------------------------
# → Retrieving material-property relationships...
#   → Collected 25 material node IDs from grounding
#   → Unique material node IDs: 23
#
#   → Searching for relationships with 41 required properties:
#     1. Key material properties & requirements for a PTFE‑substitute seal
#     2. Chemical resistance – strong acids
#     3. Chemical resistance – strong bases
#     4. Chemical resistance – oxidizers
#     5. Solvent compatibility – alkanes
#     6. Solvent compatibility – aromatics
#     7. Solvent compatibility – chlorinated hydrocarbons
#     8. Solvent compatibility – ketones
#     9. Solvent compatibility – esters
#     10. Solvent compatibility – alcohols
#     11. Solvent compatibility – polar aprotic solvents
#     12. Temperature range – up to 250 °C
#     13. Temperature range – cryogenic flexibility (–150 °C)
#     14. Mechanical integrity – high hardness
#     15. Mechanical integrity – wear resistance
#     16. Mechanical integrity – low moisture absorption (<0.01 %)
#     17. Permeability – ≤10⁻¹⁰ cm²/s for water
#     18. Compression set – <10 % after 1000 h
#     19. Coefficient of friction – ≤0.13
#     20. Wear volume – ≤10⁻⁶ mm³/N·m
#     21. Elasticity – high flexibility
#     22. Elastic recovery – minimal permanent set
#     23. Cyclic fatigue life – >10⁶ cycles
#     24. Regulatory compliance – PFAS‑free or exempt
#     25. Cost – competitive at industrial scale
#     26. Scalability – large‑volume manufacturing
#     27. Low‑hazard PLC criteria – high MW (>1000 Da)
#     28. Low‑hazard PLC criteria – negligible oligomers
#     29. Low‑hazard PLC criteria – low solubility
#     30. Dimensional stability – in aggressive solvents
#     31. Barrier properties – gas & liquid impermeability
#     32. Thermal stability – melt‑processable (ECTFE/PCTFE)
#     33. Chemical inertness – to fluorinated hydrocarbons
#     34. Mechanical durability – under pressure cycles
#     35. Seal geometry retention – during compression
#     36. Compatibility – with metal substrates (cast iron, aluminum)
#     37. Tribological performance – low wear against metals
#     38. Flexibility at low temperatures – maintain seal integrity
#     39. Resistance to plasticizers – avoid swelling
#     40. Non‑toxic – minimal leaching
#     41. Recyclability – or end‑of‑life considerations
#   [OK] Found 266 nodes, 811 edges in material relationships
#   → Sample relationship nodes: ['nickel/titanium ratio', 'phenyl ether', 'UV radiation', 'GO', 'PPS']
#   → Sample relationship edges: [('UV radiation', 'TiO2/PTES/PPS composite films'), ('GO', 'PPS'), ('GO', 'mechanical properties')]
#
# ----------------------------------------------------------------------
# Phase 1.4: Merge into Material-Informed Subgraph
# ----------------------------------------------------------------------
# → Merging filtered subgraph with material relationships...
#   → Filtered subgraph: 239 nodes, 1806 edges
#   → Material relationships: 266 nodes, 811 edges
#   [OK] Material-informed subgraph: 480 nodes, 2549 edges
#
#   Subgraph Statistics:
#     - Total nodes: 480
#     - Total edges: 2549
#     - Average degree: 10.62
#     - Estimated material nodes: 7
#     - Estimated property nodes: 0
#   ✓ Subgraph saved to persistent storage: /orcd/pool/004/tphage/SG_march/Sys3Dev/pipeline_logs/subgraphs/2026031106_0_material_informed.json
#
# ----------------------------------------------------------------------
# Phase 1.6: Extract Material Classes from Material-Informed Subgraph
# ----------------------------------------------------------------------
# → Extracting material classes from material-informed subgraph...
#   Mapping 41 properties to materials via subgraph (480 nodes)...
#   ✓ Found 17 material classes from KG
#   ✓ Found 630 paths connecting properties to materials
#   → Sample material classes:
#     1. Dextran (KG node: Dextran)
#     2. Metal-organic frameworks (MOFs) (KG node: Metal-organic frameworks (MOFs))
#     3. PEEK (KG node: PEEK)
#     4. PEG (KG node: PEG)
#     5. POM (KG node: POM)
# → Material-informed subgraph built successfully
# → Candidates will be generated iteratively in Step 2
# → Returning empty ranked_candidates list
#
# ======================================================================
# Step 1 Complete
# ======================================================================
#
# → Selecting KG paths for proposal (scored + diversity-filtered)...
#   [select_paths_for_proposal] 1864 candidate paths → 100 selected (max_paths=100, diversity_threshold=0.5)
#     Type A (property→material): 89,  Type B (property→property): 11
#   ✓ 100 paths selected for propose_candidate prompt
#
# ✓ Populated property_mapping with 17 material classes from KG
#
# ----------------------------------------------------------------------
# Step 2: Iterative Candidate Proposal and Validation
# ----------------------------------------------------------------------
#
# --- Iteration 1/5 ---
#
#   [2a] ResearchManager - Proposing candidate (avoiding 0 rejected)...
# ======================================================================
# For code tweaking purposes, we will now print the prompt for the propose candidate step and then the generated content.
# ======================================================================
# System prompt:
# You are a materials research manager specializing in material discovery and substitution.
#
# Your task: Based on property requirements and knowledge graph insights, propose a specific candidate material that can satisfy the requirements for the target application.
#
# Guidelines:
# 1. Propose concrete, specific materials (e.g., specific polymer grades, compound names) not just material classes
# 2. Ensure the candidate satisfies the required properties
# 3. Provide clear justification linking properties to the candidate
# 4. Avoid previously rejected candidates
# 5. Base your proposal on the knowledge graph insights provided
#
#
# Prompt:
# Target Application: industrial seals
#
# Required Material Properties:
#   - Key material properties & requirements for a PTFE‑substitute seal
#   - Chemical resistance – strong acids
#   - Chemical resistance – strong bases
#   - Chemical resistance – oxidizers
#   - Solvent compatibility – alkanes
#   - Solvent compatibility – aromatics
#   - Solvent compatibility – chlorinated hydrocarbons
#   - Solvent compatibility – ketones
#   - Solvent compatibility – esters
#   - Solvent compatibility – alcohols
#   - Solvent compatibility – polar aprotic solvents
#   - Temperature range – up to 250 °C
#   - Temperature range – cryogenic flexibility (–150 °C)
#   - Mechanical integrity – high hardness
#   - Mechanical integrity – wear resistance
#   - Mechanical integrity – low moisture absorption (<0.01 %)
#   - Permeability – ≤10⁻¹⁰ cm²/s for water
#   - Compression set – <10 % after 1000 h
#   - Coefficient of friction – ≤0.13
#   - Wear volume – ≤10⁻⁶ mm³/N·m
#   - Elasticity – high flexibility
#   - Elastic recovery – minimal permanent set
#   - Cyclic fatigue life – >10⁶ cycles
#   - Regulatory compliance – PFAS‑free or exempt
#   - Cost – competitive at industrial scale
#   - Scalability – large‑volume manufacturing
#   - Low‑hazard PLC criteria – high MW (>1000 Da)
#   - Low‑hazard PLC criteria – negligible oligomers
#   - Low‑hazard PLC criteria – low solubility
#   - Dimensional stability – in aggressive solvents
#   - Barrier properties – gas & liquid impermeability
#   - Thermal stability – melt‑processable (ECTFE/PCTFE)
#   - Chemical inertness – to fluorinated hydrocarbons
#   - Mechanical durability – under pressure cycles
#   - Seal geometry retention – during compression
#   - Compatibility – with metal substrates (cast iron, aluminum)
#   - Tribological performance – low wear against metals
#   - Flexibility at low temperatures – maintain seal integrity
#   - Resistance to plasticizers – avoid swelling
#   - Non‑toxic – minimal leaching
#   - Recyclability – or end‑of‑life considerations
#
#
# Knowledge Graph Insights:
#
# Key relationships (showing first 100):
#   [1] chemical resistance → [strongly_affects] → temperature → [influences reduction of] → graphene oxide → [disperses] → aprotic polar solvents
#   [2] PTFE seals → [is_tested_for] → friction coefficient → [measured] → polyurethanes
#   [3] PTFE seals → [is_tested_for] → friction coefficient → [affects] → porosity → [affects] → nanocomposite systems
#   [4] PTFE seals → [is_tested_for] → friction coefficient → [related to] → Viscosity → [has property] → TPUA
#   [5] PTFE seals → [is_tested_for] → friction coefficient → [has] → Polypropylene
#   [6] PTFE seals → [is_tested_for] → friction coefficient → [has property] → elastomer
#   [7] PTFE seals → [is_tested_for] → friction coefficient → [lowers] → graphene oxide
#   [8] PTFE seals → [is_tested_for] → friction coefficient → [has] → diamond-like carbon (DLC) coatings
#   [9] PTFE seals → [is_tested_for] → friction coefficient → [lowers to 0.002] → oxygen → [captured by] → Metal-organic frameworks (MOFs)
#   [10] PTFE seals → [is_tested_for] → friction coefficient → [is property of] → Polymer composites
#   [11] PTFE seals → [is_tested_for] → friction coefficient → [influenced by] → mechanical properties → [has enhanced] → cross-linked membranes
#   [12] PTFE seals → [is_tested_for] → friction coefficient → [is determined by at low load] → graphitic carbon
#   [13] resistance to acids and bases → [has_property] → superhydrophobic coating → [has property] → hardness → [affects] → porosity → [affects] → nanocomposite systems
#   [14] resistance to acids and bases → [has_property] → superhydrophobic coating → [used to prepare] → PDMS → [improves] → low-temperature flexibility → [has improved with increase of PU] → TPUA
#   [15] resistance to acids and bases → [has_property] → superhydrophobic coating → [has property] → wear resistance → [shows lowest wear values among the tested composites] → Polypropylene
#   [16] resistance to acids and bases → [has_property] → superhydrophobic coating → [has property] → hardness → [has] → diamond-like carbon (DLC) coatings
#   [17] chemical resistance → [strongly_affects] → temperature → [affects] → ductility → [increases with IS content] → polyurethanes
#   [18] chemical resistance → [strongly_affects] → temperature → [has no obvious effect on] → porosity → [affects] → nanocomposite systems
#   [19] chemical resistance → [strongly_affects] → temperature → [affected by] → hydrogel
#   [20] chemical resistance → [strongly_affects] → temperature → [affects] → mechanical properties → [has] → polymer materials
#   [21] chemical resistance → [strongly_affects] → temperature → [affects] → Viscosity → [has property] → TPUA
#   [22] chemical resistance → [exhibits_property] → PTFE → [mixed with] → PEEK
#   [23] chemical resistance → [strongly_affects] → temperature → [affects] → wear rate → [has] → Polypropylene
#   [24] chemical resistance → [strongly_affects] → temperature → [affects] → adhesion → [increases] → PEG
#   [25] chemical resistance → [tested against] → water → [resistant to] → elastomer
#   [26] chemical resistance → [strongly_affects] → temperature → [solubility increases with decreasing] → proteins → [minimizes non-specific adsorption for] → Dextran
#   [27] chemical resistance → [exhibits_property] → PTFE → [is_component_of] → Polymer composites
#   [28] chemical resistance → [strongly_affects] → temperature → [affects] → tribological properties → [improves] → graphitic carbon
#   [29] compression → [used to evaluate] → recyclability → [enables] → membranes → [used to fabricate] → polymer materials
#   [30] compression → [affects] → 150 degrees C → [measured up to] → friction coefficient → [has property] → PEEK
#   [31] compression → [used to evaluate] → recyclability → [endows] → PEG
#   [32] compression → [used to evaluate] → recyclability → [has property] → elastomer
#   [33] compression → [used to evaluate] → recyclability → [has_property] → Metal-organic frameworks (MOFs)
#   [34] Wear volume → [affects] → TiC content → [decreases with increasing] → friction coefficient → [affects] → elastic recovery → [has improved] → TPUA
#   [35] Scalable manufacturing → [used for] → inorganic PSCs → [used for] → ambient conditions → [affects] → friction coefficient → [measured] → polyurethanes
#   [36] chemical inertness → [has property] → diamond-like carbon (DLC) → [has property] → high hardness → [has property] → diamond-like carbon (DLC) coatings
#   [37] Cryogenic temperature (-150 degrees C, CT) → [condition_for] → Tensile experiments → [used to reveal] → mechanical properties → [has property] → PEEK → [has] → chemical inertness
#   [38] high hardness → [has property] → diamond-like carbon (DLC) coatings → [has] → friction coefficient → [related to] → frictional fatigue
#   [39] high hardness → [has property] → diamond-like carbon (DLC) coatings → [used to study] → molecular dynamics simulations → [performed at] → ambient conditions → [used for] → inorganic PSCs → [used for] → Scalable manufacturing
#   [40] Wear volume → [affects] → TiC content → [affects] → wear rate → [has] → PEEK → [has] → chemical inertness
#   [41] Wear volume → [affects] → TiC content → [decreases with increasing] → friction coefficient → [measured] → polyurethanes → [possesses] → low-temperature flexibility
#   [42] frictional fatigue → [related to] → friction coefficient → [measured] → polyurethanes → [possesses] → low-temperature flexibility
#   [43] Scalable manufacturing → [used for] → inorganic PSCs → [used for] → ambient conditions → [characterized by low modulus and high friction coefficient] → hydrogel → [is composed of] → PVA → [component_of] → PVA/GS nanocomposite films → [improves] → liquid water barrier properties
#   [44] solvent resistance → [has property] → polymer materials → [has] → rheological properties → [affects] → melt processing
#   [45] solvent resistance → [has excellent] → Polyether ether ketone (PEEK) → [has property] → mechanical properties → [has enhanced] → cross-linked membranes → [has_property] → plasticization resistance
#   [46] liquid water barrier properties → [improves] → PVA/GS nanocomposite films → [improves] → mechanical properties → [has property] → PEEK → [has] → chemical inertness
#   [47] PTFE seals → [is_component_of] → PTFE → [exhibits adhesion to] → hydrogel
#   [48] PTFE seals → [is_component_of] → PTFE → [has_property] → mechanical properties → [has] → polymer materials
#   [49] PTFE seals → [is_component_of] → PTFE → [mixed with] → PEEK
#   [50] PTFE seals → [is_component_of] → PTFE → [has reduction in due to Boric oxide] → wear rate → [results in higher] → POM
#   [51] PTFE seals → [is_component_of] → PTFE → [has] → contact angle → [reduces] → Dextran
#   [52] resistance to acids and bases → [has_property] → superhydrophobic coating → [is used to characterize] → FTIR → [characterized] → polyurethanes
#   [53] resistance to acids and bases → [has_property] → superhydrophobic coating → [affects] → protein adsorption → [undergoes] → polymer materials
#   [54] resistance to acids and bases → [has_property] → superhydrophobic coating → [has property] → adhesion → [undergoes] → PEEK
#   [55] resistance to acids and bases → [has_property] → superhydrophobic coating → [has property] → adhesion → [contributes to] → wear rate → [results in higher] → POM
#   [56] resistance to acids and bases → [has_property] → superhydrophobic coating → [cleans] → water → [resistant to] → elastomer
#   [57] resistance to acids and bases → [has_property] → superhydrophobic coating → [has property] → contact angle → [reduces] → Dextran
#   [58] resistance to acids and bases → [has_property] → superhydrophobic coating → [separates] → hydrocarbons → [used for separating] → Metal-organic frameworks (MOFs)
#   [59] resistance to acids and bases → [has_property] → superhydrophobic coating → [has property] → adhesion → [affects] → mechanical properties → [has enhanced] → cross-linked membranes
#   [60] Alkanes → [contains] → wax → [property of] → hardness → [is a property of] → PEEK
#   [61] ketones → [is converted to] → esters → [tested by] → Differential Scanning Calorimetry → [characterizes] → polymer materials
#   [62] ketones → [is converted to] → esters → [has] → tribological properties → [affects] → Viscosity → [has property] → TPUA
#   [63] ketones → [is converted to] → esters → [has] → tribological properties → [tested for] → POM
#   [64] esters → [has] → wear resistance → [enhances] → graphene oxide
#   [65] esters → [has] → wear resistance → [property of] → diamond-like carbon (DLC) coatings
#   [66] esters → [has] → wear resistance → [includes] → mechanical properties → [has enhanced] → cross-linked membranes
#   [67] temperature range of 120-270 K → [used in] → electron paramagnetic resonance spectroscopy (EPR) → [used to probe] → graphene oxide (GO) → [decreases] → friction coefficient → [measured] → polyurethanes
#   [68] high hardness → [has] → Si3N4 → [results in high friction coefficient when tested against AISI304] → friction coefficient → [measured] → polyurethanes
#   [69] wear resistance → [affects] → elastic recovery → [has improved] → TPUA
#   [70] permeability → [influences under good lubrication] → friction coefficient → [measured] → polyurethanes
#   [71] compression → [affects] → 150 degrees C → [results_in_higher] → ductility → [increases with IS content] → polyurethanes
#   [72] compression → [affects] → microstructure → [related to] → porosity → [affects] → nanocomposite systems
#   [73] compression → [affects] → 150 degrees C → [instance of] → temperature → [affected by] → hydrogel
#   [74] compression → [affects] → 150 degrees C → [is_condition_of] → heat treatment → [increases viscosity] → Viscosity → [has property] → TPUA
#   [75] compression → [affects] → 150 degrees C → [operates up to temperature] → composite → [is_material_of] → Polypropylene
#   [76] compression → [affects] → 150 degrees C → [increases] → crystallinity → [has improved] → POM
#   [77] compression → [reduces] → surface tension → [affects] → proteins → [minimizes non-specific adsorption for] → Dextran
#   [78] compression → [affects] → microstructure → [exhibits] → Polymer composites
#   [79] compression → [affects] → microstructure → [affects] → mechanical properties → [has enhanced] → cross-linked membranes
#   [80] compression → [undergoes] → diamond → [related to formation of] → graphitic carbon
#   [81] Wear volume → [affects] → TiC content → [decreases with increasing] → friction coefficient → [has_property] → hydrogel
#   [82] elastic recovery → [affects] → friction coefficient → [measured] → polyurethanes
#   [83] elastic recovery → [affects] → wear resistance → [affects] → porosity → [affects] → nanocomposite systems
#   [84] elastic recovery → [affects] → friction coefficient → [has_property] → hydrogel
#   [85] elastic recovery → [affects] → friction coefficient → [has property] → elastomer
#   [86] elastic recovery → [affects] → wear resistance → [enhances] → graphene oxide
#   [87] elastic recovery → [affects] → wear resistance → [improves with added polytetrafluoroethylene and oil] → polystyrene → [modifies] → Dextran
#   [88] elastic recovery → [affects] → wear resistance → [property of] → diamond-like carbon (DLC) coatings
#   [89] elastic recovery → [affects] → friction coefficient → [is property of] → Polymer composites
#   [90] elastic recovery → [affects] → friction coefficient → [is determined by at low load] → graphitic carbon
#   [91] frictional fatigue → [related to] → friction coefficient → [has_property] → hydrogel
#   [92] frictional fatigue → [related to] → friction coefficient → [has property] → Polyether ether ketone (PEEK) → [is a] → polymer materials
#   [93] frictional fatigue → [related to] → friction coefficient → [has property] → PEEK
#   [94] frictional fatigue → [related to] → friction coefficient → [has] → Polypropylene
#   [95] frictional fatigue → [related to] → friction coefficient → [affects] → wear rate → [results in higher] → POM
#   [96] frictional fatigue → [related to] → friction coefficient → [correlated to] → adhesion → [increases] → PEG
#   [97] frictional fatigue → [related to] → friction coefficient → [has property] → elastomer
#   [98] frictional fatigue → [related to] → friction coefficient → [lowers] → graphene oxide
#   [99] frictional fatigue → [related to] → friction coefficient → [affects as third body] → proteins → [minimizes non-specific adsorption for] → Dextran
#   [100] frictional fatigue → [related to] → friction coefficient → [is property of] → Polymer composites
#
#
# Available Materials Database (Lab Inventory):
#   1. AKROTEK® PEEK 8 natural (7343) (Dry) (ID: akro-plastic-gmbh-akrotek-peek-8-natural-7343-dry)
#   2. RILSAN® BMNO (ID: arkema-inc-rilsan-bmno)
#   3. EdgetekTM PK-000/000 (ID: avient-corporation-edgetektm-pk-000000)
#   4. KEBAPEAK PEEK XS1300 (ID: barlog-plastics-kebapeak-peek-xs1300)
#   5. FORTRON® PPS POLYPHENYLENE SULFIDE (PPS) (ID: celanese-fortron-pps-polyphenylene-sulfide-pps)
#   6. Apec® 1745 (ID: covestro-apec-1745)
#   7. Medical‑Grade Plastics Range (ID: roechling-medicalgrade-plastics-range)
#   8. VESTAKEEP® Care (ID: evonik-vestakeep-care)
#   9. GOYENCHEM-CBC450 (ID: go-yen-chemical-industrial-co-ltd-gyc-group-goyenchem-cbc450)
#   10. RT18 (ID: mitsui-tpx-rt18)
#   11. Pyramid™ KD2000-G01 (ID: polymics-ltd-pyramid-kd2000-g01)
#   12. 9101 RENOLIT INFULEX PE, EVOH (ID: renolit-9101-renolit-infulex-pe-evoh)
#   13. LEXANTM COPOLYMER XHT2146 (ID: sabic-lexantm-copolymer-xht2146)
#   14. TORELINA™ PPS resin (ID: toray-torelina-pps-resin)
#   15. Cyclic Block Copolymer (CBC) ViviOnTM 1608 (ID: usi-corporation-cyclic-block-copolymer-cbc-viviontm-1608)
#   16. ENGAGE™ 030902 HEALTH+™ Polyolefin Elastomer (ID: the-dow-chemical-company-engage-030902-health-polyolefin-elastomer)
#   17. VICTREX™ PEEK 450G (ID: victrex-plc-victrex-peek-450g)
#   18. DIC.PPS (ID: dic-corporation-dicpps)
#   19. ENGAGE™ 030902 HEALTH+™ Polyolefin Elastomer (ID: dow-chemical-company-engage-030902-health-polyolefin-elastomer)
#   20. LNPTM ELCRINTM W1000JiQ (ID: sabic-lnptm-elcrintm-w1000jiq)
#
# You may select one of these as your substitute, or combine one with a material from the retrieved sources above.
#
#
#
#
#
# Your task: Propose a specific material candidate that:
# 1. Satisfies the required properties
# 2. Is suitable for the target application
# 3. Is NOT in the rejected candidates list
# 4. Follows ONE of the two strategies below:
#    - Strategy A: Select a single material directly from the Available Materials Database above.
#    - Strategy B: Propose a composite combining one material from the Available Materials Database with a complementary material identified from the Knowledge Graph insights, listed material properties, or other retrieved sources in this prompt.
# 5. If using Strategy B, clearly identify which component comes from the database and which comes from external sources.
#
#
# Format your response EXACTLY as (use plain text, NO markdown formatting):
# Material Name: [name]
# Composition Type: [Single Material or Composite]
# Justification: [detailed reasoning]
#
# IMPORTANT: Do NOT use markdown formatting (**, *, etc.) in the Material Name field.
# Example: Material Name: [material name]
# NOT: **Material Name:** [material name] or *Material Name*: [material name]
#
# ======================================================================
# Generated content:
# Material Name: Kebapeak PEEK XS1300/PTFE Composite
# Composition Type: Composite
# Justification: The base material is Kebapeak PEEK XS1300 (ID: barlog-plastics-kebapeak-peek-xs1300), a high‑performance polyether ether ketone that melts at ~260 °C and has proven chemical resistance to strong acids, bases, oxidizers, alkanes, aromatics, chlorinated hydrocarbons, ketones, esters, alcohols, and polar aprotic solvents. Its intrinsic properties meet the temperature range (up to 250 °C), low moisture absorption (<0.01 %), high hardness, wear resistance, excellent barrier performance (water permeability <10⁻¹⁰ cm²/s), low compression set (<10 % after 1000 h), and cyclic fatigue life >10⁶ cycles. PEEK is PFAS‑free, has a molecular weight >200 kDa, negligible oligomers, and very low solubility, satisfying the low‑hazard PLC criteria.
#
# A PTFE powder filler (≈10 wt %) is incorporated into the PEEK matrix. PTFE is chemically inert to fluorinated hydrocarbons, does not swell in plasticizers, and provides a lubricating phase that reduces the coefficient of friction to ~0.05–0.08, well below the ≤0.13 requirement, while also lowering wear volume (<10⁻⁶ mm³/N·m). Because PTFE is solid at the processing temperature (melting point 327 °C), it remains dispersed during injection molding or extrusion of the composite, preserving melt‑processability and dimensional stability.
#
# The small amount of PTFE improves cryogenic flexibility: PTFE’s glass transition (~–80 °C) keeps the composite compliant down to –150 °C, mitigating the brittleness that pure PEEK would exhibit at such low temperatures. The composite retains high elasticity and minimal permanent set due to the lubricating effect of PTFE, ensuring seal geometry retention under compression.
#
# Mechanical durability under pressure cycles is maintained because PEEK’s modulus (~3–4 GPa) dominates the composite behavior; the PTFE filler does not significantly reduce stiffness but enhances wear against metal substrates. Compatibility with cast iron and aluminum is achieved through standard mechanical fastening or compatible adhesives; the composite’s surface can be treated to improve adhesion if needed.
#
# Cost and scalability are favorable: PEEK is produced in large industrial volumes, and PTFE powder is inexpensive. The composite can be processed by conventional injection molding or extrusion at 260 °C, enabling high‑volume manufacturing with competitive pricing. Recyclability is supported by PEEK’s ability to be reprocessed; the PTFE filler remains inert and does not hinder recycling.
#
# Overall, Kebapeak PEEK XS1300/PTFE Composite satisfies every listed property for a PTFE‑substitute industrial seal: it offers high‑temperature operation, cryogenic flexibility, superior chemical resistance, low friction, excellent wear performance, minimal moisture uptake, barrier integrity, regulatory compliance (PFAS‑free), mechanical durability, and scalable, cost‑effective production.
# ======================================================================
#       [PFAS] Heuristic=True, LLM=True → agree
#
#       [REJECTED] Proposed material 'Kebapeak PEEK XS1300/PTFE Composite' is a PFAS material (contains carbon-fluorine bonds)
#       → PFAS materials are not allowed per hard constraint
#       → Adding to rejected list and continuing to next iteration
#
# --- Iteration 2/5 ---
#
#   [2a.1] ResearchManager - Summarizing lessons from 1 rejected candidates...
#       [OK] Generated rejection lessons summary (2102 chars)
#       Preview: **Actionable Summary for Next Material Proposal**
#
# | # | Insight | Practical Guidance |
# |---|---------|--------------------|
# | **1** | **PFAS prohibition is absolute** – any carbon‑fluorine bond trigg...
#
#   [2a] ResearchManager - Proposing candidate (avoiding 1 rejected)...
#       Previously rejected: Kebapeak PEEK XS1300/PTFE Composite
#       → Using lessons learned from previous rejections to guide proposal
# ======================================================================
# For code tweaking purposes, we will now print the prompt for the propose candidate step and then the generated content.
# ======================================================================
# System prompt:
# You are a materials research manager specializing in material discovery and substitution.
#
# Your task: Based on property requirements and knowledge graph insights, propose a specific candidate material that can satisfy the requirements for the target application.
#
# Guidelines:
# 1. Propose concrete, specific materials (e.g., specific polymer grades, compound names) not just material classes
# 2. Ensure the candidate satisfies the required properties
# 3. Provide clear justification linking properties to the candidate
# 4. Avoid previously rejected candidates
# 5. Base your proposal on the knowledge graph insights provided
#
#
# Prompt:
# Target Application: industrial seals
#
# Required Material Properties:
#   - Key material properties & requirements for a PTFE‑substitute seal
#   - Chemical resistance – strong acids
#   - Chemical resistance – strong bases
#   - Chemical resistance – oxidizers
#   - Solvent compatibility – alkanes
#   - Solvent compatibility – aromatics
#   - Solvent compatibility – chlorinated hydrocarbons
#   - Solvent compatibility – ketones
#   - Solvent compatibility – esters
#   - Solvent compatibility – alcohols
#   - Solvent compatibility – polar aprotic solvents
#   - Temperature range – up to 250 °C
#   - Temperature range – cryogenic flexibility (–150 °C)
#   - Mechanical integrity – high hardness
#   - Mechanical integrity – wear resistance
#   - Mechanical integrity – low moisture absorption (<0.01 %)
#   - Permeability – ≤10⁻¹⁰ cm²/s for water
#   - Compression set – <10 % after 1000 h
#   - Coefficient of friction – ≤0.13
#   - Wear volume – ≤10⁻⁶ mm³/N·m
#   - Elasticity – high flexibility
#   - Elastic recovery – minimal permanent set
#   - Cyclic fatigue life – >10⁶ cycles
#   - Regulatory compliance – PFAS‑free or exempt
#   - Cost – competitive at industrial scale
#   - Scalability – large‑volume manufacturing
#   - Low‑hazard PLC criteria – high MW (>1000 Da)
#   - Low‑hazard PLC criteria – negligible oligomers
#   - Low‑hazard PLC criteria – low solubility
# ...
#          → Answer: **Answer**
#
# | Item | Source | What is reported |
# |------|--------|------------------|
# | Coefficient of friction (CoF) for **Kebapeak PEEK XS1300 + 5 wt % MoS₂** sliding against steel or aluminum at **...
#          [OK] Query 2 complete: 10 docs, answer generated
#       [3/6] Processing query: "Does exposure of Kebapeak PEEK XS1300/5 wt% MoS₂ to ≥10 % HCl, 10 % NaOH, or 10 % H₂SO₄ at 200 °C for 24 h result in measurable swelling, weight loss, or degradation as reported in the literature?"
#          → Retrieved 10 documents from RAG
#          → Top result preview: <!-- File: supplier_datasheet/Barlog-PEEK/PEEK_Barlog_Plastics_KEBAPEAK_PEEK_XS1300_TDS.md/PEEK_Barlog_Plastics_KEBAPEAK_PEEK_XS1300_TDS.mmd -->
#
#
# # T...
#          → Generating answer using ResearchManager...
#          → Answer: **Answer**
#
# | Condition | Reported effect on Kebapeak PEEK XS1300 (±5 wt % MoS₂) | Source |
# |-----------|-------|--------|
# | ≥10 % HCl, 200 °C, 24 h | No experimental data or quantitative results are ...
#          [OK] Query 3 complete: 10 docs, answer generated
#       [4/6] Processing query: "What is the compression set of Kebapeak PEEK XS1300/5 wt% MoS₂ after 1,000 h at 200 °C, and does it remain below 10 % according to published data?"
#          → Retrieved 10 documents from RAG
#          → Top result preview: <!-- File: supplier_datasheet/Barlog-PEEK/PEEK_Barlog_Plastics_KEBAPEAK_PEEK_XS1300_TDS.md/PEEK_Barlog_Plastics_KEBAPEAK_PEEK_XS1300_TDS.mmd -->
#
#
# # T...
#          → Generating answer using ResearchManager...
#          → Answer: **Compression‑set data for KEBAPEAK PEEK XS1300/5 wt % MoS₂ (1 000 h at 200 °C)**
#
# | Property | Value | Source |
# |----------|-------|--------|
# | Compression set after 1 000 h at 200 °C | **No publis...
#          [OK] Query 4 complete: 10 docs, answer generated
#       [5/6] Processing query: "Are there documented cases where Kebapeak PEEK XS1300/5 wt% MoS₂ fails to maintain dimensional stability (≤10 %) when immersed in alkanes, aromatics, chlorinated hydrocarbons, ketones, esters, alcohols, or polar aprotic solvents at 200 °C?"
#          → Retrieved 10 documents from RAG
#          → Top result preview: <!-- File: supplier_datasheet/Barlog-PEEK/PEEK_Barlog_Plastics_KEBAPEAK_PEEK_XS1300_TDS.md/PEEK_Barlog_Plastics_KEBAPEAK_PEEK_XS1300_TDS.mmd -->
#
#
# # T...
#          → Generating answer using ResearchManager...
#          → Answer: **Answer**
#
# | Question | Findings |
# |----------|----------|
# | **Do any published reports show Kebapeak PEEK XS1300 (or the 5 wt % MoS₂‑reinforced variant) losing dimensional stability beyond 10 % when...
#          [OK] Query 5 complete: 10 docs, answer generated
#       [6/6] Processing query: "Does Kebapeak PEEK XS1300/5 wt% MoS₂ contain any per‑ or polyfluoroalkyl substances (PFAS) as identified in its chemical composition reports, ensuring compliance with the PFAS exclusion constraint?"
#          → Retrieved 10 documents from RAG
#          → Top result preview: <!-- File: supplier_datasheet/Barlog-PEEK/PEEK_Barlog_Plastics_KEBAPEAK_PEEK_XS1300_TDS.md/PEEK_Barlog_Plastics_KEBAPEAK_PEEK_XS1300_TDS.mmd -->
#
#
# # T...
#          → Generating answer using ResearchManager...
#          → Answer: **Answer**
#
# | Question | Response |
# |----------|----------|
# | **Does Kebapeak PEEK XS1300/5 wt% MoS₂ contain any PFAS?** | The available material‑datasheet documents for KEBAPEAK PEEK XS1300 do not li...
#          [OK] Query 6 complete: 10 docs, answer generated
#
#   [2d] ResearchManager - Validating feasibility...
#       → Analyzing candidate 'Kebapeak PEEK XS1300 with 5 wt% MoS₂ filler' against requirements...
#       → Reviewing 6 evidence items...
#
#       Feasibility Assessment:
#          Feasible: [YES]
#          [OK] No constraints violated
#
# ======================================================================
# SUCCESS: Viable candidate material found!
# ======================================================================
#
# Final Candidate:
#    Name: Kebapeak PEEK XS1300 with 5 wt% MoS₂ filler
#    Class: Unknown
#    ID: N/A
#    Iterations required: 1/5
#
# Evidence Summary:
#    Total queries: 6
#    Total documents retrieved: 60
#    Queries with evidence: 6
# Warning: Could not extract internal iteration timing: 'str' object has no attribute 'get'
# ✓ System 2 complete - saved to /orcd/pool/004/tphage/SG_march/Sys3Dev/pipeline_logs/system2_2026031106_1.json
# ✓ System 2 duration: 765.04 seconds
# ✓ System 2 found candidate: Kebapeak PEEK XS1300 with 5 wt% MoS₂ filler
#
# --- Running System 3 (run_id: 2026031106_1) ---
# ======================================================================
# Manufacturability Assessment Pipeline: Starting Process
# ======================================================================
#
# Pipeline Configuration:
#   [OK] Candidate material: Kebapeak PEEK XS1300 with 5 wt% MoS₂ filler
#   [OK] Application: industrial seals
#   [OK] Constraints: 18 constraint(s)
#       - Hard Constraints for a PTFE‑substitute used in industrial seal applications
#       - Acid & base resistance – Must remain chemically inert (no measurable swelling, degradation or loss of mechanical integrity) when exposed to strong acids (e.g., ≥ 10 % HCl, 10 % H₂SO₄) and strong bases (e.g., ≥ 10 % NaOH, 10 % KOH) at service temperatures up to 200 °C.
#       - Oxidizer resistance – Must not degrade or lose sealing performance when exposed to common oxidizing agents (e.g., H₂O₂, O₃, Cl₂) at temperatures ≤ 200 °C.
#       - Organic solvent compatibility – Must exhibit no measurable swelling, degradation, or dimensional change in the following solvents under typical exposure conditions: alkanes, aromatics, chlorinated hydrocarbons, ketones, esters, alcohols, and polar aprotic solvents (e.g., DMF, DMSO).
#       - Dimensional stability – Must maintain dimensional changes ≤ 10 % when exposed to the chemicals above at temperatures up to 200 °C.
#       - Water‑vapor permeability – Must have a water‑vapour transmission rate ≤ 1 × 10⁻¹⁰ cm²/s (at 25 °C, 0 % RH).
#       - Temperature range – Must support continuous service from –150 °C to 250 °C without loss of sealing performance or mechanical integrity.
#       - Low‑temperature flexibility – Must remain flexible and non‑brittle down to –150 °C (i.e., no cracking or loss of elasticity at that temperature).
#       - Compression set – After 1,000 h exposure at an elevated temperature (≥ 200 °C), the material’s compression set must be < 10 %.
#       - Coefficient of friction – Under sliding contact with typical metal surfaces (e.g., steel, aluminum) the coefficient of friction must not exceed 0.13.
#       - Wear volume – The wear volume under comparable tribological testing conditions must be ≤ 1 × 10⁻⁶ mm³/N·m.
#       - Cyclic fatigue life – Must sustain ≥ 1 000 000 (10⁶) compression‑relaxation cycles at standard loading and temperature without crack initiation or propagation.
#       - PFAS exclusion – The material must contain no per‑ or polyfluoroalkyl substances (PFAS); any fluorinated content must be limited to non‑PFAS fluoropolymers that meet regulatory definitions of “low‑concern” polymers.
#       - Moisture absorption – Must absorb ≤ 0.01 % by weight when exposed to ambient humidity for 24 h.
#       - Regulatory compliance (if applicable) – If the seal is intended for use in medical or food‑contact applications, the material must be compliant with FDA 21 CFR Part 820 and relevant ISO/ASTM standards for biocompatibility and food safety.
#       - Violation of any one of these constraints would render a candidate material unsuitable as a PTFE substitute for industrial seal applications.
#       - S3[missing_critical_info]: Insufficient evidence regarding availability, cost, and lead time of raw material precursors required to produce AKROPEK® PEEK 8 natural at laboratory scale.
#       - S3 feedback: Ensure future candidates include detailed precursor sourcing information or confirm that all necessary monomers are commercially available for lab‑scale synthesis.
#   [OK] Max process families: 30
#   [OK] Temperature: 0
#   [OK] Required properties: 41 property(ies)
#   [OK] Tracker: Available
#
# ----------------------------------------------------------------------
# Step 1: Process Retrieval
# ----------------------------------------------------------------------
# → Extracting constituent materials from candidate...
# ✓ Constituents identified: 2
#   1. Kebapeak PEEK XS1300
#   2. MoS2
#   → Composite candidate detected; combination-process retrieval enabled
# → Generating decomposition-aware retrieval queries...
# ✓ Generated 9 retrieval queries (6 constituent, 3 combination)
#   1. [constituent:Kebapeak PEEK XS1300] Bulk suppliers for Kebapeak PEEK XS1300 polymer pellets suitable for injection m...
#   2. [constituent:Kebapeak PEEK XS1300] Optimal melt processing temperatures and shear rates for Kebapeak PEEK XS1300 in...
#   3. [constituent:Kebapeak PEEK XS1300] Hazardous material classification, safety data sheet (SDS) requirements, and reg...
#   4. [constituent:MoS2] Industrial suppliers of 5 wt% MoS₂ solid lubricant powder compatible with polyme...
#   5. [constituent:MoS2] Processing temperature range and mixing parameters for incorporating MoS₂ into h...
#   6. [constituent:MoS2] Safety data sheet, handling precautions, and regulatory status (e.g., REACH) for...
#   7. [combination] Compatibility assessment of Kebapeak PEEK XS1300 with 5 wt% MoS₂ filler regardin...
#   8. [combination] Recommended melt blending or extrusion compounding sequence for incorporating 5 ...
#   9. [combination] Injection molding process parameters (temperature, pressure, cooling time) requi...
#
# → Retrieving evidence from RAG sources for 9 queries...
#   [1/9] Processing query: "Bulk suppliers for Kebapeak PEEK XS1300 polymer pellets suitable for i..."
#       ✓ Retrieved 24 documents from RAG
#   [2/9] Processing query: "Optimal melt processing temperatures and shear rates for Kebapeak PEEK..."
#       ✓ Retrieved 24 documents from RAG
#   [3/9] Processing query: "Hazardous material classification, safety data sheet (SDS) requirement..."
#       ✓ Retrieved 24 documents from RAG
#   [4/9] Processing query: "Industrial suppliers of 5 wt% MoS₂ solid lubricant powder compatible w..."
#       ✓ Retrieved 24 documents from RAG
#   [5/9] Processing query: "Processing temperature range and mixing parameters for incorporating M..."
#       ✓ Retrieved 24 documents from RAG
#   [6/9] Processing query: "Safety data sheet, handling precautions, and regulatory status (e.g., ..."
#       ✓ Retrieved 24 documents from RAG
#   [7/9] Processing query: "Compatibility assessment of Kebapeak PEEK XS1300 with 5 wt% MoS₂ fille..."
#       ✓ Retrieved 24 documents from RAG
#   [8/9] Processing query: "Recommended melt blending or extrusion compounding sequence for incorp..."
#       ✓ Retrieved 24 documents from RAG
#   [9/9] Processing query: "Injection molding process parameters (temperature, pressure, cooling t..."
#       ✓ Retrieved 24 documents from RAG
#
# → Deduplicating results...
#   → Total documents before deduplication: 216
#   → Unique documents after deduplication: 30
#   → Removed 186 duplicate(s)
#   → Capped at max_process_families=30
# ✓ Collected 30 evidence items
#
# ----------------------------------------------------------------------
# Step 2: Generate Feasibility Questions
# ----------------------------------------------------------------------
# → Generating 4 feasibility assessment questions...
#   → Using 30 evidence items from Step 1 as context
# ✓ Generated 4 feasibility questions:
#   1. What raw materials (PEEK polymer or monomer) and 5 wt% MoS₂ filler are commercia...
#   2. Which laboratory equipment—such as a twin‑screw extruder, injection molding mach...
#   3. What are the optimal melt temperature, screw speed, residence time, and atmosphe...
#   4. Does using commercial KEBAPEAK PEEK XS1300 with a 5 wt% MoS₂ filler meet PFAS‑fr...
#
# ----------------------------------------------------------------------
# Step 3: Answer Feasibility Questions
# ----------------------------------------------------------------------
# → Answering 4 questions (1 LLM call per question with per-question RAG retrieval)...
#
#   [1/4] Question: "What raw materials (PEEK polymer or monomer) and 5 wt% MoS₂ filler are commercia..."
#       → Retrieving evidence for this question...
#       ✓ Retrieved 24 documents from RAG
#       → Generating answer using LLM...
#       ✓ Answer (confidence=low): Commercially available PEEK polymer suitable for lab‑scale compounding can be sourced from suppliers such as Victrex (PEEK 450G) and Roechling’s medic...
#
#   [2/4] Question: "Which laboratory equipment—such as a twin‑screw extruder, injection molding mach..."
#       → Retrieving evidence for this question...
#       ✓ Retrieved 24 documents from RAG
#       → Generating answer using LLM...
#       ✓ Answer (confidence=medium): To produce a 5 wt% MoS₂‑filled KEBAPEAK PEEK XS1300 part you would normally use two key pieces of laboratory equipment:
#
# 1. **Twin‑screw extruder (or ...
#
#   [3/4] Question: "What are the optimal melt temperature, screw speed, residence time, and atmosphe..."
#       → Retrieving evidence for this question...
#       ✓ Retrieved 24 documents from RAG
#       → Generating answer using LLM...
#       ✓ Answer (confidence=medium): For a lab‑scale twin‑screw extrusion of Kebapeak PEEK XS1300 containing 5 wt % MoS₂, the processing window is similar to that used for unfilled PEEK: ...
#
#   [4/4] Question: "Does using commercial KEBAPEAK PEEK XS1300 with a 5 wt% MoS₂ filler meet PFAS‑fr..."
#       → Retrieving evidence for this question...
#       ✓ Retrieved 24 documents from RAG
#       → Generating answer using LLM...
#       ✓ Answer (confidence=medium): Based on the supplied data, KEBAPEAK PEEK XS1300 is an unreinforced PEEK polymer and the 5 wt% MoS₂ filler contains no fluorinated groups; therefore t...
#
# ✓ All 4 questions answered
#   Confidence breakdown: {'low': 1, 'medium': 3}
#
# ----------------------------------------------------------------------
# Step 4: Feasibility Evaluation
# ----------------------------------------------------------------------
# → Evaluating overall manufacturability feasibility from Q&A pairs...
#   → Candidate: Kebapeak PEEK XS1300 with 5 wt% MoS₂ filler
#   → Application: industrial seals
#   → Q&A pairs: 4
#   → Required properties: 41 property(ies)
#   → Constraints: 18 constraint(s)
#
#   Feasibility Evaluation:
#      Feasible: [YES]
#
# ----------------------------------------------------------------------
# Step 5: Recipe Synthesis
# ----------------------------------------------------------------------
# → Synthesizing process recipe...
# ✓ Generated 5 process steps
# ✓ Evidence items: 5
#
#   Process Recipe Preview:
#     Step 1: Dry the PEEK pellets and MoS₂ powder to remove moisture.
#     Step 2: Pre‑mix the dried polymer and filler in a high‑shear mixer or twin‑scr...
#     Step 3: Melt‑compound the mixture to produce strands, pelletise and cool.
#     ... and 2 more step(s)
#
# ✓ Saved chat log to /orcd/pool/004/tphage/SG_march/Sys3Dev/pipeline_logs/chats/system3_chat_log_manufacturability_assessment_2026031106_1.json
#
# ======================================================================
# Manufacturability Assessment: Process Complete
# ======================================================================
# Summary:
#   - Status: MANUFACTURABLE
#   - Evidence items retrieved (Step 1): 30
#   - Feasibility questions asked: 4
#   - Process recipe steps: 5
#   - Evidence items in recipe: 5
# ======================================================================
# ✓ System 3 complete - saved to /orcd/pool/004/tphage/SG_march/Sys3Dev/pipeline_logs/system3_2026031106_1.json
# ✓ System 3 duration: 480.73 seconds
#
# System 3 Status: MANUFACTURABLE
#
# ======================================================================
# ✓ SUCCESS: Found manufacturable candidate!
# ======================================================================
#
# ======================================================================
# System 2 → System 3 Loop Complete
# ======================================================================
# Total iterations: 2
# Final status: manufacturable

# %%
print("=" * 70)
print("HIERARCHICAL SYSTEM EXECUTION SUMMARY")
print("=" * 70)

print(f"\nSystem 1 (Property Extraction):")
print(f"  Run ID: {system1_run_id}")
print(f"  Properties extracted: {len(properties_W.get('required', []))}")
print(f"  Output: {os.path.join(output_dir, f'system1_{system1_run_id}.json')}")

print(f"\nSystem 2 → System 3 Loop:")
print(f"  Total iterations: {len(all_iterations)}")
print(f"  Max iterations allowed: {max_iterations}")

for iter_data in all_iterations:
    iter_num = iter_data["iteration"]
    s2_run_id = iter_data["system2_run_id"]
    s2_success = iter_data["system2_success"]
    candidate = iter_data.get("candidate", "N/A")
    s3_run_id = iter_data.get("system3_run_id", "N/A")
    s3_status = iter_data.get("system3_status", "N/A")
    
    print(f"\n  Iteration {iter_num}:")
    print(f"    System 2: {'✓ Success' if s2_success else '✗ Failed'} (run_id: {s2_run_id})")
    if s2_success:
        print(f"      Candidate: {candidate}")
        print(f"    System 3: {s3_status.upper()} (run_id: {s3_run_id})")
        if s3_status == "blocked":
            # Load System 3 result to show feedback
            s3_path = os.path.join(output_dir, f"system3_{s3_run_id}.json")
            if os.path.exists(s3_path):
                with open(s3_path, "r") as f:
                    s3_data = json.load(f)
                feedback = s3_data.get("feedback_to_system2", "")
                if feedback:
                    print(f"      Feedback: {feedback[:150]}...")

print(f"\nFinal Result:")
if all_iterations:
    final_iter = all_iterations[-1]
    final_status = final_iter.get("system3_status", "N/A")
    final_candidate = final_iter.get("candidate", "N/A")
    
    if final_status == "manufacturable":
        print(f"  ✓ SUCCESS: Found manufacturable candidate!")
        print(f"  Candidate: {final_candidate}")
        print(f"  System 3 Run ID: {final_iter.get('system3_run_id', 'N/A')}")
        
        # Load and display process recipe if available
        s3_path = os.path.join(output_dir, f"system3_{final_iter.get('system3_run_id', '')}.json")
        if os.path.exists(s3_path):
            with open(s3_path, "r") as f:
                s3_data = json.load(f)
            recipe = s3_data.get("process_recipe", [])
            if recipe:
                print(f"\n  Process Recipe ({len(recipe)} steps):")
                for step in recipe[:3]:  # Show first 3 steps
                    step_idx = step.get("step_index", "?")
                    desc = step.get("description", "")[:100]
                    print(f"    Step {step_idx}: {desc}...")
                if len(recipe) > 3:
                    print(f"    ... and {len(recipe) - 3} more steps")
    elif final_status == "blocked":
        print(f"  ✗ BLOCKED: Candidate rejected after {len(all_iterations)} iteration(s)")
        print(f"  Final candidate: {final_candidate}")
        if len(all_iterations) >= max_iterations:
            print(f"  Max iterations ({max_iterations}) reached")
    else:
        print(f"  Status: {final_status}")
else:
    print("  No iterations completed")

print(f"\nTracker Status:")
rejected = tracker.get_all_rejected()
print(f"  Total rejected candidates: {len(rejected)}")
if rejected:
    print(f"  Rejected materials:")
    for i, mat in enumerate(rejected[:5], 1):
        print(f"    {i}. {mat}")
    if len(rejected) > 5:
        print(f"    ... and {len(rejected) - 5} more")

print("\n" + "=" * 70)

# Update final outcome in pipeline_run
if all_iterations:
    final_iter = all_iterations[-1]
    final_status = final_iter.get("system3_status", "N/A")
    final_candidate = final_iter.get("candidate", "N/A")
    
    if final_status == "manufacturable":
        pipeline_run["final_outcome"]["status"] = "manufacturable"
    elif final_status == "blocked":
        if len(all_iterations) >= max_iterations:
            pipeline_run["final_outcome"]["status"] = "max_iterations_reached"
        else:
            pipeline_run["final_outcome"]["status"] = "blocked"
    else:
        pipeline_run["final_outcome"]["status"] = final_status
    
    pipeline_run["final_outcome"]["final_candidate"] = final_candidate
else:
    pipeline_run["final_outcome"]["status"] = "no_iterations_completed"

pipeline_run["final_outcome"]["total_rejected_candidates"] = len(tracker.get_all_rejected())

# Calculate total duration and update pipeline_run
pipeline_end_time = datetime.utcnow()
pipeline_total_duration = (pipeline_end_time - pipeline_start_time).total_seconds()
pipeline_run["end_time"] = pipeline_end_time.isoformat() + "Z"
pipeline_run["total_duration_seconds"] = pipeline_total_duration

# Save PipelineRun object
pipeline_run_output_path = os.path.join(output_dir, f"pipeline_run_{pipeline_run_id}.json")
with open(pipeline_run_output_path, "w", encoding="utf-8") as f:
    json.dump(pipeline_run, f, indent=2, ensure_ascii=False, default=str)

print(f"\n✓ PipelineRun object saved to {pipeline_run_output_path}")
print(f"✓ Total pipeline duration: {pipeline_total_duration:.2f} seconds ({pipeline_total_duration/60:.2f} minutes)")

# Save evaluation-ready JSON for material scientist evaluation
eval_path = save_evaluation_export(pipeline_run, output_dir)
if eval_path:
    print(f"✓ Evaluation export saved to {eval_path}")
# Out:
# ======================================================================
# HIERARCHICAL SYSTEM EXECUTION SUMMARY
# ======================================================================
#
# System 1 (Property Extraction):
#   Run ID: 2026031106_0
#   Properties extracted: 41
#   Output: /orcd/pool/004/tphage/SG_march/Sys3Dev/pipeline_logs/system1_2026031106_0.json
#
# System 2 → System 3 Loop:
#   Total iterations: 2
#   Max iterations allowed: 3
#
#   Iteration 1:
#     System 2: ✓ Success (run_id: 2026031106_0)
#       Candidate: AKROPEK® PEEK 8 natural (7343) (Dry
#     System 3: BLOCKED (run_id: 2026031106_0)
#       Feedback: Ensure future candidates include detailed precursor sourcing information or confirm that all necessary monomers are commercially available for lab‑sca...
#
#   Iteration 2:
#     System 2: ✓ Success (run_id: 2026031106_1)
#       Candidate: Kebapeak PEEK XS1300 with 5 wt% MoS₂ filler
#     System 3: MANUFACTURABLE (run_id: 2026031106_1)
#
# Final Result:
#   ✓ SUCCESS: Found manufacturable candidate!
#   Candidate: Kebapeak PEEK XS1300 with 5 wt% MoS₂ filler
#   System 3 Run ID: 2026031106_1
#
#   Process Recipe (5 steps):
#     Step 1: Dry the PEEK pellets and MoS₂ powder to remove moisture....
#     Step 2: Pre‑mix the dried polymer and filler in a high‑shear mixer or twin‑screw extruder to achieve uniform...
#     Step 3: Melt‑compound the mixture to produce strands, pelletise and cool....
#     ... and 2 more steps
#
# Tracker Status:
#   Total rejected candidates: 3
#   Rejected materials:
#     1. Kebapeak PEEK XS1300/PTFE Composite
#     2. AKROPEEK‑GF/POE Seal
#     3. AKROPEK® PEEK 8 natural (7343) (Dry
#
# ======================================================================
#
# ✓ PipelineRun object saved to /orcd/pool/004/tphage/SG_march/Sys3Dev/pipeline_logs/pipeline_run_2026031106.json
# ✓ Total pipeline duration: 3505.94 seconds (58.43 minutes)
# ✓ Evaluation export saved to /orcd/pool/004/tphage/SG_march/Sys3Dev/pipeline_logs/evaluation_2026031106.json
